# %% [markdown]
# # Day 2: Cube Conundrum

# %%
# *** [AoC DAY 2 Challenge] ***
# =====================================================================================================================
import re

# ! Open the file for reading mode (= default mode if the mode is not specified)
file = open("../data/23_day-2_input.txt", "r")

# Read all the data in the file
arrFileData = file.read()
# Split the data read from the file by every new line encountered and store in an array list
arrFileData = arrFileData.split('\n')

# # ! Read all lines in the .txt file and store each line as a string in an array list
# arrFileData = file.readlines()

# # arrFileData = []

# # while True:
# #     line = file.readline()
# #     arrFileData.append(line)
        
# #     if not line:
# # 	    break

# file.close()

# # ! Remove new line('\n') from each string in array list
# for line in arrFileData:
#     #line = line.replace("\n", "")
#     line = line.strip()
#     #print(line[-1])

print(arrFileData)
print(len(arrFileData))

# ====================================================================================================================
# Out:
# ['Game 1: 13 red, 18 green; 5 green, 3 red, 5 blue; 5 green, 9 red, 6 blue; 3 blue, 3 green', 'Game 2: 2 green, 3 blue, 5 red; 9 green, 4 red, 2 blue; 4 green, 3 blue; 2 blue, 3 red; 5 red, 3 blue, 9 green; 9 green, 5 red, 2 blue', 'Game 3: 12 green, 3 red, 3 blue; 2 blue, 5 green, 2 red; 2 red, 3 blue, 11 green; 2 red, 8 green, 7 blue', 'Game 4: 1 green, 2 blue; 7 green, 13 red; 2 blue, 5 green, 7 red; 6 green, 2 red', 'Game 5: 6 blue, 4 green; 8 blue, 7 green; 1 red, 10 blue', 'Game 6: 4 red, 4 blue, 2 green; 8 green, 1 blue, 8 red; 9 green, 1 red, 3 blue', 'Game 7: 3 red, 12 green, 4 blue; 1 blue, 3 red, 6 green; 4 blue, 3 red, 15 green; 11 green, 2 blue, 2 red', 'Game 8: 13 blue, 7 green, 8 red; 5 green, 8 blue, 2 red; 5 red, 6 blue, 7 green; 6 green, 6 red, 3 blue; 7 blue, 8 red, 6 green', 'Game 9: 4 blue, 1 green, 4 red; 16 red, 1 green, 7 blue; 11 red, 3 green, 7 blue', 'Game 10: 5 green, 1 red; 5 green, 3 blue; 1 red, 7 green, 3 blue; 1 blue, 6 green; 2 green, 4 blue', 'Game 11: 10 green, 2 blue, 2 red; 14 green, 1 blue, 3 red; 13 green; 3 green, 2 red; 3 red, 1 blue, 2 green; 1 red, 10 green, 2 blue', 'Game 12: 9 green, 2 blue; 11 green, 1 blue; 2 red, 1 blue; 1 blue, 2 red, 3 green; 1 blue, 2 red, 3 green', 'Game 13: 11 blue, 3 red, 8 green; 9 red, 7 blue; 7 blue, 4 red', 'Game 14: 17 blue, 2 red; 1 green, 13 blue, 1 red; 4 blue, 1 red, 4 green; 2 blue, 5 red, 13 green; 3 blue, 4 green, 6 red; 9 green, 14 blue, 6 red', 'Game 15: 7 green, 2 blue, 3 red; 4 red, 18 green; 8 green, 1 blue; 3 red, 15 green, 2 blue; 1 red, 15 green; 9 green, 3 red, 1 blue', 'Game 16: 10 red, 19 blue, 5 green; 12 red, 5 blue; 6 red, 3 green, 14 blue; 8 red, 10 blue, 6 green; 7 green, 10 red, 17 blue', 'Game 17: 3 green, 3 red, 1 blue; 3 blue, 1 green, 2 red; 4 green, 3 red, 2 blue', 'Game 18: 1 red, 2 blue; 1 green, 4 blue; 1 blue; 5 blue; 1 green, 3 red, 6 blue', 'Game 19: 3 blue, 5 red, 8 green; 10 red, 6 blue, 11 green; 5 blue, 7 red, 8 green; 9 blue, 6 green, 5 red; 8 red, 12 green, 8 blue; 1 blue, 5 green, 10 red', 'Game 20: 16 blue, 2 green; 10 green, 1 red, 4 blue; 13 green, 5 red, 9 blue', 'Game 21: 1 blue, 1 green, 14 red; 2 blue; 5 green, 1 blue; 2 green, 11 red; 2 red, 4 green; 2 green, 16 red', 'Game 22: 1 green, 10 red, 4 blue; 1 green, 4 blue, 8 red; 2 blue, 8 red; 4 green, 14 red; 1 blue, 5 red, 2 green', 'Game 23: 17 green, 3 red, 16 blue; 9 green, 15 red; 3 red, 8 blue, 15 green', 'Game 24: 1 green, 1 blue; 2 blue, 1 green, 2 red; 3 green, 1 blue, 1 red; 3 blue, 1 red; 2 green, 5 blue', 'Game 25: 11 red, 2 green; 7 red, 6 green; 10 red, 1 blue, 8 green; 8 green, 4 red; 6 green, 10 red; 2 blue, 7 red', 'Game 26: 2 green, 2 blue, 8 red; 1 blue, 1 red, 6 green; 9 red, 6 green, 2 blue', 'Game 27: 5 red, 7 blue, 3 green; 3 blue, 1 red; 1 green, 1 red, 9 blue', 'Game 28: 17 red, 5 green, 10 blue; 3 red, 14 blue, 1 green; 11 blue, 11 green', 'Game 29: 16 red, 4 green, 4 blue; 3 green, 5 blue, 11 red; 7 blue, 8 red, 1 green; 1 green, 10 red, 4 blue; 2 green, 4 blue, 8 red', 'Game 30: 3 green, 6 blue; 18 green, 3 blue; 14 green, 11 blue; 7 blue, 2 red, 17 green; 1 red, 12 green, 7 blue', 'Game 31: 11 red, 2 green, 3 blue; 10 green, 11 blue, 15 red; 12 green, 17 blue, 5 red; 5 green, 2 red, 12 blue; 13 blue, 13 green, 4 red', 'Game 32: 4 red, 2 blue, 5 green; 7 blue, 15 red; 11 blue, 4 green, 8 red', 'Game 33: 18 blue, 3 green, 3 red; 3 green, 6 red; 2 blue, 4 red, 1 green; 3 green, 5 red, 3 blue', 'Game 34: 5 red, 2 blue, 16 green; 9 red, 10 blue, 3 green; 8 red, 10 green, 13 blue', 'Game 35: 7 blue, 5 red; 3 red, 1 blue; 4 blue, 7 red, 1 green; 4 red, 4 blue, 1 green; 3 blue, 7 red; 4 red, 1 green, 3 blue', 'Game 36: 14 blue; 10 blue, 1 green; 10 blue, 4 green; 4 blue, 1 green, 1 red; 1 red, 6 blue, 4 green; 1 green, 1 red, 11 blue', 'Game 37: 8 red, 13 green, 5 blue; 11 red, 16 green, 8 blue; 2 green, 10 blue, 11 red', 'Game 38: 2 red, 1 blue, 10 green; 7 red, 6 blue, 14 green; 18 red, 1 blue, 5 green; 5 green, 5 blue, 13 red; 14  ...
# 100

# %% [markdown]
# ## Part 1

# %%
# *** [PART 1] ***
# ! As you walk, the Elf shows you a small bag and some cubes which are either red, green, or blue. 
# - Each time you play this game, he will hide a secret number of cubes of each color in the bag.
# - Your goal is to figure out *information* about the number of cubes.
# - The Elf would first like to know which games would have been possible if the bag contained ONLY: 
#   - [12 red cubes], [13 green cubes], and [14 blue cubes]
# --------------------------------------------------------------------------------------------------------------------
# TODO: Create vars that store max value restriction for how many coloured cubes exist in the bag 
#       for EACH set in EACH game
max_red = 12
max_green = 13
max_blue = 14

counter = 0 # counter var to keep track of the ID of EACH game
sumPossibleIDs = 0 # var to store the sum of IDs of POSSIBLE games

# TODO: Traverse through each game in the array list var 'arrFileData':
# - In EACH set in EACH game, IF the number of cubes for a particular colour cube in the CURRENT game's set 
#   is greater than (>) the maximum number of cubes for that specific colour in the bag, then the CURRENT game 
#   is regarded as NOT possible.
for game in arrFileData:
    counter = counter + 1 # increment counter for ID of CURRENT game

    num_red = 0 # var stores the total number of red coloured cubes in EACH set of EACH game
    num_green = 0
    num_blue = 0

    nonPossibleSetFound = 0 # var to determine if a non possible set has been found in the CURRENT game

    print(game)
    arrGameSplit = game.split(':')
    arrGameSets = arrGameSplit[1]
    print(arrGameSets)
    #arrGameSets = re.split('[,;]', arrGameSets) # multiple delimiters: '[xxx]' > e.g. '[,;:]'
    arrGameSets = arrGameSets.split(';')
    print(arrGameSets)

    # TODO: Traverse through EACH set in the CURRENT game
    for gameSet in arrGameSets:
        arrCubeValues = [] # var to store the number and colour of every cube drawn in EACH set for the CURRENT game

        # Separate the number of cubes drawn in the CURRENT set of the CURRENT game
        arrGameSet = gameSet.strip().split(',')
        #print("#", arrGameSet)

        # TODO: Traverse through EACH cube drawn in the CURRENT set of the CURRENT game
        for cube in arrGameSet:
            arrCubeValues = cube.strip().split(' ') # E.g ['3 red'] => ['3', 'red']
            print("#", arrCubeValues)

            # ! Check if 'red/green/blue' exists in the CURRENT value of the CURRENT set in the CURRENT game
            # - IF the respective colour exists, then set the respective number to the var holding the total
            #   number of cubes for that particular colour in the CURRENT set of the CURRENT game
            if arrCubeValues[1] == 'red':
                num_red = int(arrCubeValues[0])

            if arrCubeValues[1] == 'green':
                num_green = int(arrCubeValues[0])

            if arrCubeValues[1] == 'blue':
                num_blue = int(arrCubeValues[0])

        #print('#red:', num_red, '#green:', num_green, '#blue:', num_blue)

        # TODO: CHECK if the CURRENT set in the CURRENT game is POSSIBLE
        # - ALL sets in the CURRENT game MUST pass this check for the game to be deemed POSSIBLE
        if (num_red <= max_red) and (num_green <= max_green) and (num_blue <= max_blue):
            #sumPossibleIDs = sumPossibleIDs + counter
            print("POSSIBLE SET IN CURRENT GAME")
        else:
            nonPossibleSetFound = 1
            print("NON POSSIBLE SET IN CURRENT GAME")

    if nonPossibleSetFound == 0:
        sumPossibleIDs = sumPossibleIDs + counter
        print("--- POSSIBLE GAME ---")
    else:
        print("--- NON POSSIBLE GAME ---")

print("Sum of possible game IDs:", sumPossibleIDs)
# --------------------------------------------------------------------------------------------------------------------
    # ! Traverse through EACH set's values in the CURRENT game
    #for gameSet in arrGameSets: 

        # # ! Check if 'red' exists in the CURRENT value of the CURRENT set in the CURRENT game
        # if gameSet.find('red') != -1:
        #     arrDigits = re.findall(r'\d', gameSet)
        #     # IF the respective colour exists, then add the respective number to the var holding the sum of cubes
        #     # for that particular colour in the CURRENT game
        #     if arrDigits:
        #         number = '' # var to store built string number value

        #         # for ALL found digits in the CURRENT value of the CURRENT set in the CURRENT game
        #         for digit in arrDigits:
        #             number = number + digit # append digit to string number var - e.g. '2' + '1' = '21'

        #         num_red = num_red + int(number)

        # # ! Check if 'green' exists in the CURRENT value of the CURRENT set in the CURRENT game
        # if gameSet.find('green') != -1:
        #     arrDigits = re.findall(r'\d', gameSet)
        #     # IF the respective colour exists, then add the respective number to the var holding the sum of cubes
        #     # for that particular colour in the CURRENT game
        #     if arrDigits:
        #         number = '' # var to store built string number value

        #         # for ALL found digits in the CURRENT value of the CURRENT set in the CURRENT game
        #         for digit in arrDigits:
        #             number = number + digit # append digit to string number var - e.g. '2' + '1' = '21'

        #         num_green = num_green + int(number)

        # # ! Check if 'blue' exists in the CURRENT value of the CURRENT set in the CURRENT game
        # if gameSet.find('blue') != -1:
        #     arrDigits = re.findall(r'\d', gameSet)
        #     # IF the respective colour exists, then add the respective number to the var holding the sum of cubes
        #     # for that particular colour in the CURRENT game
        #     if arrDigits:
        #         number = '' # var to store built string number value

        #         # for ALL found digits in the CURRENT value of the CURRENT set in the CURRENT game
        #         for digit in arrDigits:
        #             number = number + digit # append digit to string number var - e.g. '2' + '1' = '21'

        #         num_blue = num_blue + int(number)
    
#     print('#red:', num_red, '#green:', num_green, '#blue:', num_blue)

#     if (num_red <= max_red) and (num_green <= max_green) and (num_blue <= max_blue):
#         sumPossibleIDs = sumPossibleIDs + counter

#         print("POSSIBLE")
#     else:
#         print("NOT POSSIBLE")
# Out:
# Game 1: 13 red, 18 green; 5 green, 3 red, 5 blue; 5 green, 9 red, 6 blue; 3 blue, 3 green
#  13 red, 18 green; 5 green, 3 red, 5 blue; 5 green, 9 red, 6 blue; 3 blue, 3 green
# [' 13 red, 18 green', ' 5 green, 3 red, 5 blue', ' 5 green, 9 red, 6 blue', ' 3 blue, 3 green']
# # ['13', 'red']
# # ['18', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['3', 'red']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['9', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 2: 2 green, 3 blue, 5 red; 9 green, 4 red, 2 blue; 4 green, 3 blue; 2 blue, 3 red; 5 red, 3 blue, 9 green; 9 green, 5 red, 2 blue
#  2 green, 3 blue, 5 red; 9 green, 4 red, 2 blue; 4 green, 3 blue; 2 blue, 3 red; 5 red, 3 blue, 9 green; 9 green, 5 red, 2 blue
# [' 2 green, 3 blue, 5 red', ' 9 green, 4 red, 2 blue', ' 4 green, 3 blue', ' 2 blue, 3 red', ' 5 red, 3 blue, 9 green', ' 9 green, 5 red, 2 blue']
# # ['2', 'green']
# # ['3', 'blue']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['4', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['3', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['5', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 3: 12 green, 3 red, 3 blue; 2 blue, 5 green, 2 red; 2 red, 3 blue, 11 green; 2 red, 8 green, 7 blue
#  12 green, 3 red, 3 blue; 2 blue, 5 green, 2 red; 2 red, 3 blue, 11 green; 2 red, 8 green, 7 blue
# [' 12 green, 3 red, 3 blue', ' 2 blue, 5 green, 2 red', ' 2 red, 3 blue, 11 green', ' 2 red, 8 green, 7 blue']
# # ['12', 'green']
# # ['3', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['5', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['3', 'blue']
# # ['11', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['8', 'green']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 4: 1 green, 2 blue; 7 green, 13 red; 2 blue, 5 green, 7 red; 6 green, 2 red
#  1 green, 2 blue; 7 green, 13 red; 2 blue, 5 green, 7 red; 6 green, 2 red
# [' 1 green, 2 blue', ' 7 green, 13 red', ' 2 blue, 5 green, 7 red', ' 6 green, 2 red']
# # ['1', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['13', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['5', 'green']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 5: 6 blue, 4 green; 8 blue, 7 green; 1 red, 10 blue
#  6 blue, 4 green; 8 blue, 7 green; 1 red, 10 blue
# [' 6 blue, 4 green', ' 8 blue, 7 green', ' 1 red, 10 blue']
# # ['6', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'blue']
# # ['7', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['10', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 6: 4 red, 4 blue, 2 green; 8 green, 1 blue, 8 red; 9 green, 1 red, 3 blue
#  4 red, 4 blue, 2 green; 8 green, 1 blue, 8 red; 9 green, 1 red, 3 blue
# [' 4 red, 4 blue, 2 green', ' 8 green, 1 blue, 8 red', ' 9 green, 1 red, 3 blue']
# # ['4', 'red']
# # ['4', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['1', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 7: 3 red, 12 green, 4 blue; 1 blue, 3 red, 6 green; 4 blue, 3 red, 15 green; 11 green, 2 blue, 2 red
#  3 red, 12 green, 4 blue; 1 blue, 3 red, 6 green; 4 blue, 3 red, 15 green; 11 green, 2 blue, 2 red
# [' 3 red, 12 green, 4 blue', ' 1 blue, 3 red, 6 green', ' 4 blue, 3 red, 15 green', ' 11 green, 2 blue, 2 red']
# # ['3', 'red']
# # ['12', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['3', 'red']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['3', 'red']
# # ['15', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['11', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 8: 13 blue, 7 green, 8 red; 5 green, 8 blue, 2 red; 5 red, 6 blue, 7 green; 6 green, 6 red, 3 blue; 7 blue, 8 red, 6 green
#  13 blue, 7 green, 8 red; 5 green, 8 blue, 2 red; 5 red, 6 blue, 7 green; 6 green, 6 red, 3 blue; 7 blue, 8 red, 6 green
# [' 13 blue, 7 green, 8 red', ' 5 green, 8 blue, 2 red', ' 5 red, 6 blue, 7 green', ' 6 green, 6 red, 3 blue', ' 7 blue, 8 red, 6 green']
# # ['13', 'blue']
# # ['7', 'green']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['8', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['6', 'blue']
# # ['7', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['6', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['8', 'red']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 9: 4 blue, 1 green, 4 red; 16 red, 1 green, 7 blue; 11 red, 3 green, 7 blue
#  4 blue, 1 green, 4 red; 16 red, 1 green, 7 blue; 11 red, 3 green, 7 blue
# [' 4 blue, 1 green, 4 red', ' 16 red, 1 green, 7 blue', ' 11 red, 3 green, 7 blue']
# # ['4', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['16', 'red']
# # ['1', 'green']
# # ['7', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['11', 'red']
# # ['3', 'green']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 10: 5 green, 1 red; 5 green, 3 blue; 1 red, 7 green, 3 blue; 1 blue, 6 green; 2 green, 4 blue
#  5 green, 1 red; 5 green, 3 blue; 1 red, 7 green, 3 blue; 1 blue, 6 green; 2 green, 4 blue
# [' 5 green, 1 red', ' 5 green, 3 blue', ' 1 red, 7 green, 3 blue', ' 1 blue, 6 green', ' 2 green, 4 blue']
# # ['5', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['7', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 11: 10 green, 2 blue, 2 red; 14 green, 1 blue, 3 red; 13 green; 3 green, 2 red; 3 red, 1 blue, 2 green; 1 red, 10 green, 2 blue
#  10 green, 2 blue, 2 red; 14 green, 1 blue, 3 red; 13 green; 3 green, 2 red; 3 red, 1 blue, 2 green; 1 red, 10 green, 2 blue
# [' 10 green, 2 blue, 2 red', ' 14 green, 1 blue, 3 red', ' 13 green', ' 3 green, 2 red', ' 3 red, 1 blue, 2 green', ' 1 red, 10 green, 2 blue']
# # ['10', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['14', 'green']
# # ['1', 'blue']
# # ['3', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['13', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['1', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['10', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 12: 9 green, 2 blue; 11 green, 1 blue; 2 red, 1 blue; 1 blue, 2 red, 3 green; 1 blue, 2 red, 3 green
#  9 green, 2 blue; 11 green, 1 blue; 2 red, 1 blue; 1 blue, 2 red, 3 green; 1 blue, 2 red, 3 green
# [' 9 green, 2 blue', ' 11 green, 1 blue', ' 2 red, 1 blue', ' 1 blue, 2 red, 3 green', ' 1 blue, 2 red, 3 green']
# # ['9', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['2', 'red']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['2', 'red']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 13: 11 blue, 3 red, 8 green; 9 red, 7 blue; 7 blue, 4 red
#  11 blue, 3 red, 8 green; 9 red, 7 blue; 7 blue, 4 red
# [' 11 blue, 3 red, 8 green', ' 9 red, 7 blue', ' 7 blue, 4 red']
# # ['11', 'blue']
# # ['3', 'red']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'red']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 14: 17 blue, 2 red; 1 green, 13 blue, 1 red; 4 blue, 1 red, 4 green; 2 blue, 5 red, 13 green; 3 blue, 4 green, 6 red; 9 green, 14 blue, 6 red
#  17 blue, 2 red; 1 green, 13 blue, 1 red; 4 blue, 1 red, 4 green; 2 blue, 5 red, 13 green; 3 blue, 4 green, 6 red; 9 green, 14 blue, 6 red
# [' 17 blue, 2 red', ' 1 green, 13 blue, 1 red', ' 4 blue, 1 red, 4 green', ' 2 blue, 5 red, 13 green', ' 3 blue, 4 green, 6 red', ' 9 green, 14 blue, 6 red']
# # ['17', 'blue']
# # ['2', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['13', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['1', 'red']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['5', 'red']
# # ['13', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['4', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['14', 'blue']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 15: 7 green, 2 blue, 3 red; 4 red, 18 green; 8 green, 1 blue; 3 red, 15 green, 2 blue; 1 red, 15 green; 9 green, 3 red, 1 blue
#  7 green, 2 blue, 3 red; 4 red, 18 green; 8 green, 1 blue; 3 red, 15 green, 2 blue; 1 red, 15 green; 9 green, 3 red, 1 blue
# [' 7 green, 2 blue, 3 red', ' 4 red, 18 green', ' 8 green, 1 blue', ' 3 red, 15 green, 2 blue', ' 1 red, 15 green', ' 9 green, 3 red, 1 blue']
# # ['7', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['18', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['15', 'green']
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['15', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 16: 10 red, 19 blue, 5 green; 12 red, 5 blue; 6 red, 3 green, 14 blue; 8 red, 10 blue, 6 green; 7 green, 10 red, 17 blue
#  10 red, 19 blue, 5 green; 12 red, 5 blue; 6 red, 3 green, 14 blue; 8 red, 10 blue, 6 green; 7 green, 10 red, 17 blue
# [' 10 red, 19 blue, 5 green', ' 12 red, 5 blue', ' 6 red, 3 green, 14 blue', ' 8 red, 10 blue, 6 green', ' 7 green, 10 red, 17 blue']
# # ['10', 'red']
# # ['19', 'blue']
# # ['5', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['12', 'red']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'red']
# # ['3', 'green']
# # ['14', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'red']
# # ['10', 'blue']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['10', 'red']
# # ['17', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 17: 3 green, 3 red, 1 blue; 3 blue, 1 green, 2 red; 4 green, 3 red, 2 blue
#  3 green, 3 red, 1 blue; 3 blue, 1 green, 2 red; 4 green, 3 red, 2 blue
# [' 3 green, 3 red, 1 blue', ' 3 blue, 1 green, 2 red', ' 4 green, 3 red, 2 blue']
# # ['3', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['3', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 18: 1 red, 2 blue; 1 green, 4 blue; 1 blue; 5 blue; 1 green, 3 red, 6 blue
#  1 red, 2 blue; 1 green, 4 blue; 1 blue; 5 blue; 1 green, 3 red, 6 blue
# [' 1 red, 2 blue', ' 1 green, 4 blue', ' 1 blue', ' 5 blue', ' 1 green, 3 red, 6 blue']
# # ['1', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['3', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 19: 3 blue, 5 red, 8 green; 10 red, 6 blue, 11 green; 5 blue, 7 red, 8 green; 9 blue, 6 green, 5 red; 8 red, 12 green, 8 blue; 1 blue, 5 green, 10 red
#  3 blue, 5 red, 8 green; 10 red, 6 blue, 11 green; 5 blue, 7 red, 8 green; 9 blue, 6 green, 5 red; 8 red, 12 green, 8 blue; 1 blue, 5 green, 10 red
# [' 3 blue, 5 red, 8 green', ' 10 red, 6 blue, 11 green', ' 5 blue, 7 red, 8 green', ' 9 blue, 6 green, 5 red', ' 8 red, 12 green, 8 blue', ' 1 blue, 5 green, 10 red']
# # ['3', 'blue']
# # ['5', 'red']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'red']
# # ['6', 'blue']
# # ['11', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# # ['7', 'red']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['6', 'green']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'red']
# # ['12', 'green']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'green']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 20: 16 blue, 2 green; 10 green, 1 red, 4 blue; 13 green, 5 red, 9 blue
#  16 blue, 2 green; 10 green, 1 red, 4 blue; 13 green, 5 red, 9 blue
# [' 16 blue, 2 green', ' 10 green, 1 red, 4 blue', ' 13 green, 5 red, 9 blue']
# # ['16', 'blue']
# # ['2', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['1', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['13', 'green']
# # ['5', 'red']
# # ['9', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 21: 1 blue, 1 green, 14 red; 2 blue; 5 green, 1 blue; 2 green, 11 red; 2 red, 4 green; 2 green, 16 red
#  1 blue, 1 green, 14 red; 2 blue; 5 green, 1 blue; 2 green, 11 red; 2 red, 4 green; 2 green, 16 red
# [' 1 blue, 1 green, 14 red', ' 2 blue', ' 5 green, 1 blue', ' 2 green, 11 red', ' 2 red, 4 green', ' 2 green, 16 red']
# # ['1', 'blue']
# # ['1', 'green']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['1', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['16', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 22: 1 green, 10 red, 4 blue; 1 green, 4 blue, 8 red; 2 blue, 8 red; 4 green, 14 red; 1 blue, 5 red, 2 green
#  1 green, 10 red, 4 blue; 1 green, 4 blue, 8 red; 2 blue, 8 red; 4 green, 14 red; 1 blue, 5 red, 2 green
# [' 1 green, 10 red, 4 blue', ' 1 green, 4 blue, 8 red', ' 2 blue, 8 red', ' 4 green, 14 red', ' 1 blue, 5 red, 2 green']
# # ['1', 'green']
# # ['10', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 23: 17 green, 3 red, 16 blue; 9 green, 15 red; 3 red, 8 blue, 15 green
#  17 green, 3 red, 16 blue; 9 green, 15 red; 3 red, 8 blue, 15 green
# [' 17 green, 3 red, 16 blue', ' 9 green, 15 red', ' 3 red, 8 blue, 15 green']
# # ['17', 'green']
# # ['3', 'red']
# # ['16', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['15', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['8', 'blue']
# # ['15', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 24: 1 green, 1 blue; 2 blue, 1 green, 2 red; 3 green, 1 blue, 1 red; 3 blue, 1 red; 2 green, 5 blue
#  1 green, 1 blue; 2 blue, 1 green, 2 red; 3 green, 1 blue, 1 red; 3 blue, 1 red; 2 green, 5 blue
# [' 1 green, 1 blue', ' 2 blue, 1 green, 2 red', ' 3 green, 1 blue, 1 red', ' 3 blue, 1 red', ' 2 green, 5 blue']
# # ['1', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['1', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 25: 11 red, 2 green; 7 red, 6 green; 10 red, 1 blue, 8 green; 8 green, 4 red; 6 green, 10 red; 2 blue, 7 red
#  11 red, 2 green; 7 red, 6 green; 10 red, 1 blue, 8 green; 8 green, 4 red; 6 green, 10 red; 2 blue, 7 red
# [' 11 red, 2 green', ' 7 red, 6 green', ' 10 red, 1 blue, 8 green', ' 8 green, 4 red', ' 6 green, 10 red', ' 2 blue, 7 red']
# # ['11', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'red']
# # ['1', 'blue']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 26: 2 green, 2 blue, 8 red; 1 blue, 1 red, 6 green; 9 red, 6 green, 2 blue
#  2 green, 2 blue, 8 red; 1 blue, 1 red, 6 green; 9 red, 6 green, 2 blue
# [' 2 green, 2 blue, 8 red', ' 1 blue, 1 red, 6 green', ' 9 red, 6 green, 2 blue']
# # ['2', 'green']
# # ['2', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['1', 'red']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'red']
# # ['6', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 27: 5 red, 7 blue, 3 green; 3 blue, 1 red; 1 green, 1 red, 9 blue
#  5 red, 7 blue, 3 green; 3 blue, 1 red; 1 green, 1 red, 9 blue
# [' 5 red, 7 blue, 3 green', ' 3 blue, 1 red', ' 1 green, 1 red, 9 blue']
# # ['5', 'red']
# # ['7', 'blue']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['1', 'red']
# # ['9', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 28: 17 red, 5 green, 10 blue; 3 red, 14 blue, 1 green; 11 blue, 11 green
#  17 red, 5 green, 10 blue; 3 red, 14 blue, 1 green; 11 blue, 11 green
# [' 17 red, 5 green, 10 blue', ' 3 red, 14 blue, 1 green', ' 11 blue, 11 green']
# # ['17', 'red']
# # ['5', 'green']
# # ['10', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['14', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'blue']
# # ['11', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 29: 16 red, 4 green, 4 blue; 3 green, 5 blue, 11 red; 7 blue, 8 red, 1 green; 1 green, 10 red, 4 blue; 2 green, 4 blue, 8 red
#  16 red, 4 green, 4 blue; 3 green, 5 blue, 11 red; 7 blue, 8 red, 1 green; 1 green, 10 red, 4 blue; 2 green, 4 blue, 8 red
# [' 16 red, 4 green, 4 blue', ' 3 green, 5 blue, 11 red', ' 7 blue, 8 red, 1 green', ' 1 green, 10 red, 4 blue', ' 2 green, 4 blue, 8 red']
# # ['16', 'red']
# # ['4', 'green']
# # ['4', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['5', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['8', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['10', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 30: 3 green, 6 blue; 18 green, 3 blue; 14 green, 11 blue; 7 blue, 2 red, 17 green; 1 red, 12 green, 7 blue
#  3 green, 6 blue; 18 green, 3 blue; 14 green, 11 blue; 7 blue, 2 red, 17 green; 1 red, 12 green, 7 blue
# [' 3 green, 6 blue', ' 18 green, 3 blue', ' 14 green, 11 blue', ' 7 blue, 2 red, 17 green', ' 1 red, 12 green, 7 blue']
# # ['3', 'green']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['18', 'green']
# # ['3', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['14', 'green']
# # ['11', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['2', 'red']
# # ['17', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['12', 'green']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 31: 11 red, 2 green, 3 blue; 10 green, 11 blue, 15 red; 12 green, 17 blue, 5 red; 5 green, 2 red, 12 blue; 13 blue, 13 green, 4 red
#  11 red, 2 green, 3 blue; 10 green, 11 blue, 15 red; 12 green, 17 blue, 5 red; 5 green, 2 red, 12 blue; 13 blue, 13 green, 4 red
# [' 11 red, 2 green, 3 blue', ' 10 green, 11 blue, 15 red', ' 12 green, 17 blue, 5 red', ' 5 green, 2 red, 12 blue', ' 13 blue, 13 green, 4 red']
# # ['11', 'red']
# # ['2', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['11', 'blue']
# # ['15', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['12', 'green']
# # ['17', 'blue']
# # ['5', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['2', 'red']
# # ['12', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['13', 'blue']
# # ['13', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 32: 4 red, 2 blue, 5 green; 7 blue, 15 red; 11 blue, 4 green, 8 red
#  4 red, 2 blue, 5 green; 7 blue, 15 red; 11 blue, 4 green, 8 red
# [' 4 red, 2 blue, 5 green', ' 7 blue, 15 red', ' 11 blue, 4 green, 8 red']
# # ['4', 'red']
# # ['2', 'blue']
# # ['5', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['15', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['11', 'blue']
# # ['4', 'green']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 33: 18 blue, 3 green, 3 red; 3 green, 6 red; 2 blue, 4 red, 1 green; 3 green, 5 red, 3 blue
#  18 blue, 3 green, 3 red; 3 green, 6 red; 2 blue, 4 red, 1 green; 3 green, 5 red, 3 blue
# [' 18 blue, 3 green, 3 red', ' 3 green, 6 red', ' 2 blue, 4 red, 1 green', ' 3 green, 5 red, 3 blue']
# # ['18', 'blue']
# # ['3', 'green']
# # ['3', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['6', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['4', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['5', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 34: 5 red, 2 blue, 16 green; 9 red, 10 blue, 3 green; 8 red, 10 green, 13 blue
#  5 red, 2 blue, 16 green; 9 red, 10 blue, 3 green; 8 red, 10 green, 13 blue
# [' 5 red, 2 blue, 16 green', ' 9 red, 10 blue, 3 green', ' 8 red, 10 green, 13 blue']
# # ['5', 'red']
# # ['2', 'blue']
# # ['16', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'red']
# # ['10', 'blue']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'red']
# # ['10', 'green']
# # ['13', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 35: 7 blue, 5 red; 3 red, 1 blue; 4 blue, 7 red, 1 green; 4 red, 4 blue, 1 green; 3 blue, 7 red; 4 red, 1 green, 3 blue
#  7 blue, 5 red; 3 red, 1 blue; 4 blue, 7 red, 1 green; 4 red, 4 blue, 1 green; 3 blue, 7 red; 4 red, 1 green, 3 blue
# [' 7 blue, 5 red', ' 3 red, 1 blue', ' 4 blue, 7 red, 1 green', ' 4 red, 4 blue, 1 green', ' 3 blue, 7 red', ' 4 red, 1 green, 3 blue']
# # ['7', 'blue']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['7', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['4', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 36: 14 blue; 10 blue, 1 green; 10 blue, 4 green; 4 blue, 1 green, 1 red; 1 red, 6 blue, 4 green; 1 green, 1 red, 11 blue
#  14 blue; 10 blue, 1 green; 10 blue, 4 green; 4 blue, 1 green, 1 red; 1 red, 6 blue, 4 green; 1 green, 1 red, 11 blue
# [' 14 blue', ' 10 blue, 1 green', ' 10 blue, 4 green', ' 4 blue, 1 green, 1 red', ' 1 red, 6 blue, 4 green', ' 1 green, 1 red, 11 blue']
# # ['14', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['1', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['6', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['1', 'red']
# # ['11', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 37: 8 red, 13 green, 5 blue; 11 red, 16 green, 8 blue; 2 green, 10 blue, 11 red
#  8 red, 13 green, 5 blue; 11 red, 16 green, 8 blue; 2 green, 10 blue, 11 red
# [' 8 red, 13 green, 5 blue', ' 11 red, 16 green, 8 blue', ' 2 green, 10 blue, 11 red']
# # ['8', 'red']
# # ['13', 'green']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'red']
# # ['16', 'green']
# # ['8', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['10', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 38: 2 red, 1 blue, 10 green; 7 red, 6 blue, 14 green; 18 red, 1 blue, 5 green; 5 green, 5 blue, 13 red; 14 red, 5 green; 15 green, 13 red, 2 blue
#  2 red, 1 blue, 10 green; 7 red, 6 blue, 14 green; 18 red, 1 blue, 5 green; 5 green, 5 blue, 13 red; 14 red, 5 green; 15 green, 13 red, 2 blue
# [' 2 red, 1 blue, 10 green', ' 7 red, 6 blue, 14 green', ' 18 red, 1 blue, 5 green', ' 5 green, 5 blue, 13 red', ' 14 red, 5 green', ' 15 green, 13 red, 2 blue']
# # ['2', 'red']
# # ['1', 'blue']
# # ['10', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['6', 'blue']
# # ['14', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['18', 'red']
# # ['1', 'blue']
# # ['5', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['5', 'blue']
# # ['13', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['14', 'red']
# # ['5', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['15', 'green']
# # ['13', 'red']
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 39: 1 blue, 5 red; 9 red, 9 green; 4 blue, 10 green, 4 red; 3 green, 11 red, 1 blue; 2 green, 11 red, 4 blue
#  1 blue, 5 red; 9 red, 9 green; 4 blue, 10 green, 4 red; 3 green, 11 red, 1 blue; 2 green, 11 red, 4 blue
# [' 1 blue, 5 red', ' 9 red, 9 green', ' 4 blue, 10 green, 4 red', ' 3 green, 11 red, 1 blue', ' 2 green, 11 red, 4 blue']
# # ['1', 'blue']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'red']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['10', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['11', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['11', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 40: 9 blue, 4 green; 12 green, 1 red; 2 red, 15 green, 10 blue
#  9 blue, 4 green; 12 green, 1 red; 2 red, 15 green, 10 blue
# [' 9 blue, 4 green', ' 12 green, 1 red', ' 2 red, 15 green, 10 blue']
# # ['9', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['12', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['15', 'green']
# # ['10', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 41: 1 blue, 14 red, 12 green; 16 green, 2 blue, 3 red; 6 green, 9 red
#  1 blue, 14 red, 12 green; 16 green, 2 blue, 3 red; 6 green, 9 red
# [' 1 blue, 14 red, 12 green', ' 16 green, 2 blue, 3 red', ' 6 green, 9 red']
# # ['1', 'blue']
# # ['14', 'red']
# # ['12', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['16', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['9', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 42: 4 green, 13 red, 9 blue; 9 green, 9 red, 4 blue; 7 blue, 10 red, 9 green; 4 green, 18 blue, 14 red; 9 blue, 7 green, 2 red
#  4 green, 13 red, 9 blue; 9 green, 9 red, 4 blue; 7 blue, 10 red, 9 green; 4 green, 18 blue, 14 red; 9 blue, 7 green, 2 red
# [' 4 green, 13 red, 9 blue', ' 9 green, 9 red, 4 blue', ' 7 blue, 10 red, 9 green', ' 4 green, 18 blue, 14 red', ' 9 blue, 7 green, 2 red']
# # ['4', 'green']
# # ['13', 'red']
# # ['9', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['9', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['10', 'red']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['18', 'blue']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['7', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 43: 7 red, 6 blue; 4 green; 3 red, 6 green; 7 blue, 6 green, 8 red; 9 green, 7 blue, 7 red; 5 blue, 5 green, 6 red
#  7 red, 6 blue; 4 green; 3 red, 6 green; 7 blue, 6 green, 8 red; 9 green, 7 blue, 7 red; 5 blue, 5 green, 6 red
# [' 7 red, 6 blue', ' 4 green', ' 3 red, 6 green', ' 7 blue, 6 green, 8 red', ' 9 green, 7 blue, 7 red', ' 5 blue, 5 green, 6 red']
# # ['7', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['6', 'green']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['7', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# # ['5', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 44: 5 red, 8 blue; 2 red, 5 green; 6 green, 11 blue, 2 red; 1 green, 1 blue, 2 red
#  5 red, 8 blue; 2 red, 5 green; 6 green, 11 blue, 2 red; 1 green, 1 blue, 2 red
# [' 5 red, 8 blue', ' 2 red, 5 green', ' 6 green, 11 blue, 2 red', ' 1 green, 1 blue, 2 red']
# # ['5', 'red']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['5', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['11', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 45: 3 blue, 7 green, 1 red; 5 red, 1 blue; 2 blue, 3 red; 8 green, 5 red
#  3 blue, 7 green, 1 red; 5 red, 1 blue; 2 blue, 3 red; 8 green, 5 red
# [' 3 blue, 7 green, 1 red', ' 5 red, 1 blue', ' 2 blue, 3 red', ' 8 green, 5 red']
# # ['3', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 46: 4 red, 4 blue, 17 green; 1 blue, 5 green, 1 red; 1 red, 1 blue, 7 green; 18 green, 7 blue
#  4 red, 4 blue, 17 green; 1 blue, 5 green, 1 red; 1 red, 1 blue, 7 green; 18 green, 7 blue
# [' 4 red, 4 blue, 17 green', ' 1 blue, 5 green, 1 red', ' 1 red, 1 blue, 7 green', ' 18 green, 7 blue']
# # ['4', 'red']
# # ['4', 'blue']
# # ['17', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['1', 'blue']
# # ['7', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['18', 'green']
# # ['7', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 47: 14 red, 3 green, 2 blue; 4 green, 4 red, 2 blue; 13 red, 1 blue
#  14 red, 3 green, 2 blue; 4 green, 4 red, 2 blue; 13 red, 1 blue
# [' 14 red, 3 green, 2 blue', ' 4 green, 4 red, 2 blue', ' 13 red, 1 blue']
# # ['14', 'red']
# # ['3', 'green']
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['4', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['13', 'red']
# # ['1', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 48: 5 red, 12 blue, 2 green; 3 blue, 1 red, 2 green; 10 blue, 7 red
#  5 red, 12 blue, 2 green; 3 blue, 1 red, 2 green; 10 blue, 7 red
# [' 5 red, 12 blue, 2 green', ' 3 blue, 1 red, 2 green', ' 10 blue, 7 red']
# # ['5', 'red']
# # ['12', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 49: 6 blue, 11 red; 11 red, 17 blue, 11 green; 16 blue, 12 green, 6 red
#  6 blue, 11 red; 11 red, 17 blue, 11 green; 16 blue, 12 green, 6 red
# [' 6 blue, 11 red', ' 11 red, 17 blue, 11 green', ' 16 blue, 12 green, 6 red']
# # ['6', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'red']
# # ['17', 'blue']
# # ['11', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['16', 'blue']
# # ['12', 'green']
# # ['6', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 50: 12 blue, 3 green, 1 red; 3 green, 10 blue, 3 red; 11 blue, 3 red
#  12 blue, 3 green, 1 red; 3 green, 10 blue, 3 red; 11 blue, 3 red
# [' 12 blue, 3 green, 1 red', ' 3 green, 10 blue, 3 red', ' 11 blue, 3 red']
# # ['12', 'blue']
# # ['3', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['10', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 51: 12 green, 1 blue, 8 red; 6 blue, 1 green, 9 red; 17 red, 5 blue; 7 blue, 9 green, 9 red; 13 green, 10 red, 2 blue
#  12 green, 1 blue, 8 red; 6 blue, 1 green, 9 red; 17 red, 5 blue; 7 blue, 9 green, 9 red; 13 green, 10 red, 2 blue
# [' 12 green, 1 blue, 8 red', ' 6 blue, 1 green, 9 red', ' 17 red, 5 blue', ' 7 blue, 9 green, 9 red', ' 13 green, 10 red, 2 blue']
# # ['12', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['1', 'green']
# # ['9', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['17', 'red']
# # ['5', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['9', 'green']
# # ['9', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['13', 'green']
# # ['10', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 52: 5 blue, 1 green; 1 red, 1 green, 3 blue; 8 blue, 1 green; 1 green, 7 blue; 3 blue; 1 red, 6 blue
#  5 blue, 1 green; 1 red, 1 green, 3 blue; 8 blue, 1 green; 1 green, 7 blue; 3 blue; 1 red, 6 blue
# [' 5 blue, 1 green', ' 1 red, 1 green, 3 blue', ' 8 blue, 1 green', ' 1 green, 7 blue', ' 3 blue', ' 1 red, 6 blue']
# # ['5', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 53: 11 green, 5 red; 16 green, 6 blue; 4 red, 19 green, 4 blue
#  11 green, 5 red; 16 green, 6 blue; 4 red, 19 green, 4 blue
# [' 11 green, 5 red', ' 16 green, 6 blue', ' 4 red, 19 green, 4 blue']
# # ['11', 'green']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['16', 'green']
# # ['6', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['19', 'green']
# # ['4', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 54: 6 green, 4 blue, 8 red; 7 red, 6 green, 5 blue; 5 blue, 4 red; 5 blue, 14 red
#  6 green, 4 blue, 8 red; 7 red, 6 green, 5 blue; 5 blue, 4 red; 5 blue, 14 red
# [' 6 green, 4 blue, 8 red', ' 7 red, 6 green, 5 blue', ' 5 blue, 4 red', ' 5 blue, 14 red']
# # ['6', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['6', 'green']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 55: 11 blue, 1 green; 2 red, 5 blue, 1 green; 10 blue, 1 green; 11 blue; 2 green, 2 red, 5 blue
#  11 blue, 1 green; 2 red, 5 blue, 1 green; 10 blue, 1 green; 11 blue; 2 green, 2 red, 5 blue
# [' 11 blue, 1 green', ' 2 red, 5 blue, 1 green', ' 10 blue, 1 green', ' 11 blue', ' 2 green, 2 red, 5 blue']
# # ['11', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['5', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['2', 'red']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 56: 1 red, 9 blue, 1 green; 2 red, 8 blue; 1 green, 9 blue, 10 red; 5 blue, 1 green; 15 blue, 1 red; 12 blue, 4 red
#  1 red, 9 blue, 1 green; 2 red, 8 blue; 1 green, 9 blue, 10 red; 5 blue, 1 green; 15 blue, 1 red; 12 blue, 4 red
# [' 1 red, 9 blue, 1 green', ' 2 red, 8 blue', ' 1 green, 9 blue, 10 red', ' 5 blue, 1 green', ' 15 blue, 1 red', ' 12 blue, 4 red']
# # ['1', 'red']
# # ['9', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['9', 'blue']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['15', 'blue']
# # ['1', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['12', 'blue']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 57: 1 green, 17 blue; 10 blue, 2 green; 2 red, 16 blue; 6 green, 15 blue; 5 green; 2 red, 1 green
#  1 green, 17 blue; 10 blue, 2 green; 2 red, 16 blue; 6 green, 15 blue; 5 green; 2 red, 1 green
# [' 1 green, 17 blue', ' 10 blue, 2 green', ' 2 red, 16 blue', ' 6 green, 15 blue', ' 5 green', ' 2 red, 1 green']
# # ['1', 'green']
# # ['17', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['16', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['15', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['1', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 58: 2 blue, 4 green, 2 red; 5 blue; 5 red, 3 green, 2 blue; 5 red, 2 green, 5 blue; 7 green, 3 red, 4 blue; 4 red
#  2 blue, 4 green, 2 red; 5 blue; 5 red, 3 green, 2 blue; 5 red, 2 green, 5 blue; 7 green, 3 red, 4 blue; 4 red
# [' 2 blue, 4 green, 2 red', ' 5 blue', ' 5 red, 3 green, 2 blue', ' 5 red, 2 green, 5 blue', ' 7 green, 3 red, 4 blue', ' 4 red']
# # ['2', 'blue']
# # ['4', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['3', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['2', 'green']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['3', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 59: 8 blue, 2 red, 2 green; 15 blue, 1 green, 4 red; 9 blue, 1 red; 3 green, 5 red, 5 blue
#  8 blue, 2 red, 2 green; 15 blue, 1 green, 4 red; 9 blue, 1 red; 3 green, 5 red, 5 blue
# [' 8 blue, 2 red, 2 green', ' 15 blue, 1 green, 4 red', ' 9 blue, 1 red', ' 3 green, 5 red, 5 blue']
# # ['8', 'blue']
# # ['2', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['15', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['5', 'red']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 60: 3 red, 2 blue, 6 green; 1 red, 5 green; 2 blue, 10 green; 6 green, 2 red
#  3 red, 2 blue, 6 green; 1 red, 5 green; 2 blue, 10 green; 6 green, 2 red
# [' 3 red, 2 blue, 6 green', ' 1 red, 5 green', ' 2 blue, 10 green', ' 6 green, 2 red']
# # ['3', 'red']
# # ['2', 'blue']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['5', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['10', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 61: 6 green, 4 blue; 1 red, 4 blue, 15 green; 1 blue, 16 green, 3 red; 6 red, 12 green, 2 blue; 3 red, 14 green, 1 blue; 3 red, 2 blue, 9 green
#  6 green, 4 blue; 1 red, 4 blue, 15 green; 1 blue, 16 green, 3 red; 6 red, 12 green, 2 blue; 3 red, 14 green, 1 blue; 3 red, 2 blue, 9 green
# [' 6 green, 4 blue', ' 1 red, 4 blue, 15 green', ' 1 blue, 16 green, 3 red', ' 6 red, 12 green, 2 blue', ' 3 red, 14 green, 1 blue', ' 3 red, 2 blue, 9 green']
# # ['6', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['4', 'blue']
# # ['15', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['16', 'green']
# # ['3', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'red']
# # ['12', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['14', 'green']
# # ['1', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'red']
# # ['2', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 62: 1 green, 2 red; 4 red; 1 green, 4 red, 1 blue; 1 red, 1 blue, 1 green
#  1 green, 2 red; 4 red; 1 green, 4 red, 1 blue; 1 red, 1 blue, 1 green
# [' 1 green, 2 red', ' 4 red', ' 1 green, 4 red, 1 blue', ' 1 red, 1 blue, 1 green']
# # ['1', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['4', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 63: 8 green, 4 red, 4 blue; 5 red, 4 blue, 8 green; 3 green, 1 blue
#  8 green, 4 red, 4 blue; 5 red, 4 blue, 8 green; 3 green, 1 blue
# [' 8 green, 4 red, 4 blue', ' 5 red, 4 blue, 8 green', ' 3 green, 1 blue']
# # ['8', 'green']
# # ['4', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['4', 'blue']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 64: 5 blue, 2 green, 5 red; 3 green, 2 blue, 1 red; 6 blue, 2 red, 1 green; 2 green, 2 blue, 3 red; 3 blue, 1 red
#  5 blue, 2 green, 5 red; 3 green, 2 blue, 1 red; 6 blue, 2 red, 1 green; 2 green, 2 blue, 3 red; 3 blue, 1 red
# [' 5 blue, 2 green, 5 red', ' 3 green, 2 blue, 1 red', ' 6 blue, 2 red, 1 green', ' 2 green, 2 blue, 3 red', ' 3 blue, 1 red']
# # ['5', 'blue']
# # ['2', 'green']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['2', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 65: 2 red, 7 green, 5 blue; 8 blue, 3 green, 4 red; 1 red, 6 green, 1 blue
#  2 red, 7 green, 5 blue; 8 blue, 3 green, 4 red; 1 red, 6 green, 1 blue
# [' 2 red, 7 green, 5 blue', ' 8 blue, 3 green, 4 red', ' 1 red, 6 green, 1 blue']
# # ['2', 'red']
# # ['7', 'green']
# # ['5', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'blue']
# # ['3', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['6', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 66: 1 green, 6 red; 5 red, 1 green, 1 blue; 4 red, 1 blue, 1 green; 1 blue, 2 red, 1 green; 1 blue, 5 red; 1 blue, 8 red
#  1 green, 6 red; 5 red, 1 green, 1 blue; 4 red, 1 blue, 1 green; 1 blue, 2 red, 1 green; 1 blue, 5 red; 1 blue, 8 red
# [' 1 green, 6 red', ' 5 red, 1 green, 1 blue', ' 4 red, 1 blue, 1 green', ' 1 blue, 2 red, 1 green', ' 1 blue, 5 red', ' 1 blue, 8 red']
# # ['1', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'red']
# # ['1', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 67: 6 red, 8 blue, 8 green; 5 green, 2 red, 10 blue; 4 red, 1 green; 7 blue, 2 green
#  6 red, 8 blue, 8 green; 5 green, 2 red, 10 blue; 4 red, 1 green; 7 blue, 2 green
# [' 6 red, 8 blue, 8 green', ' 5 green, 2 red, 10 blue', ' 4 red, 1 green', ' 7 blue, 2 green']
# # ['6', 'red']
# # ['8', 'blue']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['2', 'red']
# # ['10', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 68: 7 green, 9 red, 15 blue; 4 green, 6 red, 3 blue; 1 blue, 5 green, 4 red; 9 green, 14 red, 6 blue; 8 blue, 15 red, 4 green; 7 green, 14 blue, 6 red
#  7 green, 9 red, 15 blue; 4 green, 6 red, 3 blue; 1 blue, 5 green, 4 red; 9 green, 14 red, 6 blue; 8 blue, 15 red, 4 green; 7 green, 14 blue, 6 red
# [' 7 green, 9 red, 15 blue', ' 4 green, 6 red, 3 blue', ' 1 blue, 5 green, 4 red', ' 9 green, 14 red, 6 blue', ' 8 blue, 15 red, 4 green', ' 7 green, 14 blue, 6 red']
# # ['7', 'green']
# # ['9', 'red']
# # ['15', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['6', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['14', 'red']
# # ['6', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['8', 'blue']
# # ['15', 'red']
# # ['4', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['14', 'blue']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 69: 4 green; 2 blue; 4 green, 8 blue, 11 red; 3 green, 9 red, 4 blue; 1 red, 2 blue; 2 green, 5 blue, 11 red
#  4 green; 2 blue; 4 green, 8 blue, 11 red; 3 green, 9 red, 4 blue; 1 red, 2 blue; 2 green, 5 blue, 11 red
# [' 4 green', ' 2 blue', ' 4 green, 8 blue, 11 red', ' 3 green, 9 red, 4 blue', ' 1 red, 2 blue', ' 2 green, 5 blue, 11 red']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['8', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['9', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['5', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 70: 6 blue, 16 green, 4 red; 6 green, 13 red, 2 blue; 7 green, 1 red, 2 blue; 8 green, 4 blue, 1 red; 10 red, 11 green
#  6 blue, 16 green, 4 red; 6 green, 13 red, 2 blue; 7 green, 1 red, 2 blue; 8 green, 4 blue, 1 red; 10 red, 11 green
# [' 6 blue, 16 green, 4 red', ' 6 green, 13 red, 2 blue', ' 7 green, 1 red, 2 blue', ' 8 green, 4 blue, 1 red', ' 10 red, 11 green']
# # ['6', 'blue']
# # ['16', 'green']
# # ['4', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'green']
# # ['13', 'red']
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['1', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['4', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'red']
# # ['11', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 71: 6 blue, 7 red; 10 blue, 2 green, 4 red; 12 red, 10 blue, 1 green
#  6 blue, 7 red; 10 blue, 2 green, 4 red; 12 red, 10 blue, 1 green
# [' 6 blue, 7 red', ' 10 blue, 2 green, 4 red', ' 12 red, 10 blue, 1 green']
# # ['6', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['2', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['12', 'red']
# # ['10', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 72: 13 red, 13 blue; 6 red, 10 blue, 7 green; 3 blue, 5 green, 4 red; 8 green, 9 blue
#  13 red, 13 blue; 6 red, 10 blue, 7 green; 3 blue, 5 green, 4 red; 8 green, 9 blue
# [' 13 red, 13 blue', ' 6 red, 10 blue, 7 green', ' 3 blue, 5 green, 4 red', ' 8 green, 9 blue']
# # ['13', 'red']
# # ['13', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'red']
# # ['10', 'blue']
# # ['7', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['5', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['9', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 73: 1 red, 1 green, 8 blue; 1 green, 8 blue; 2 green, 6 blue; 2 blue; 1 red, 12 blue; 12 blue, 3 green
#  1 red, 1 green, 8 blue; 1 green, 8 blue; 2 green, 6 blue; 2 blue; 1 red, 12 blue; 12 blue, 3 green
# [' 1 red, 1 green, 8 blue', ' 1 green, 8 blue', ' 2 green, 6 blue', ' 2 blue', ' 1 red, 12 blue', ' 12 blue, 3 green']
# # ['1', 'red']
# # ['1', 'green']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['12', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['12', 'blue']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 74: 2 blue, 1 green, 1 red; 3 blue, 1 red, 1 green; 3 blue, 2 red; 3 blue, 1 red; 1 green
#  2 blue, 1 green, 1 red; 3 blue, 1 red, 1 green; 3 blue, 2 red; 3 blue, 1 red; 1 green
# [' 2 blue, 1 green, 1 red', ' 3 blue, 1 red, 1 green', ' 3 blue, 2 red', ' 3 blue, 1 red', ' 1 green']
# # ['2', 'blue']
# # ['1', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 75: 10 red, 1 green, 4 blue; 12 red, 11 blue, 9 green; 18 green, 14 red, 5 blue
#  10 red, 1 green, 4 blue; 12 red, 11 blue, 9 green; 18 green, 14 red, 5 blue
# [' 10 red, 1 green, 4 blue', ' 12 red, 11 blue, 9 green', ' 18 green, 14 red, 5 blue']
# # ['10', 'red']
# # ['1', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['12', 'red']
# # ['11', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# ...
# [' 2 red, 10 blue, 6 green', ' 6 blue, 2 red, 8 green', ' 1 red, 9 green, 7 blue']
# # ['2', 'red']
# # ['10', 'blue']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['2', 'red']
# # ['8', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['9', 'green']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 78: 3 green, 10 red; 2 blue, 4 red, 3 green; 8 red, 3 blue, 4 green; 1 blue, 7 red
#  3 green, 10 red; 2 blue, 4 red, 3 green; 8 red, 3 blue, 4 green; 1 blue, 7 red
# [' 3 green, 10 red', ' 2 blue, 4 red, 3 green', ' 8 red, 3 blue, 4 green', ' 1 blue, 7 red']
# # ['3', 'green']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['4', 'red']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'red']
# # ['3', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 79: 4 green, 2 red; 2 red, 14 green; 1 blue, 5 green, 8 red; 4 red, 20 green; 3 green, 1 blue, 8 red; 4 green, 1 blue
#  4 green, 2 red; 2 red, 14 green; 1 blue, 5 green, 8 red; 4 red, 20 green; 3 green, 1 blue, 8 red; 4 green, 1 blue
# [' 4 green, 2 red', ' 2 red, 14 green', ' 1 blue, 5 green, 8 red', ' 4 red, 20 green', ' 3 green, 1 blue, 8 red', ' 4 green, 1 blue']
# # ['4', 'green']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'red']
# # ['14', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['5', 'green']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['20', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 80: 2 green; 3 green, 13 red, 10 blue; 6 blue, 10 red, 1 green; 10 green, 12 red, 3 blue; 10 blue, 17 red, 5 green; 8 red, 2 blue, 6 green
#  2 green; 3 green, 13 red, 10 blue; 6 blue, 10 red, 1 green; 10 green, 12 red, 3 blue; 10 blue, 17 red, 5 green; 8 red, 2 blue, 6 green
# [' 2 green', ' 3 green, 13 red, 10 blue', ' 6 blue, 10 red, 1 green', ' 10 green, 12 red, 3 blue', ' 10 blue, 17 red, 5 green', ' 8 red, 2 blue, 6 green']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['13', 'red']
# # ['10', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['10', 'red']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['12', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['17', 'red']
# # ['5', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['8', 'red']
# # ['2', 'blue']
# # ['6', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 81: 4 green, 2 blue, 4 red; 16 red, 1 blue, 20 green; 7 blue, 10 red, 9 green; 7 blue, 2 green, 14 red
#  4 green, 2 blue, 4 red; 16 red, 1 blue, 20 green; 7 blue, 10 red, 9 green; 7 blue, 2 green, 14 red
# [' 4 green, 2 blue, 4 red', ' 16 red, 1 blue, 20 green', ' 7 blue, 10 red, 9 green', ' 7 blue, 2 green, 14 red']
# # ['4', 'green']
# # ['2', 'blue']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['16', 'red']
# # ['1', 'blue']
# # ['20', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['10', 'red']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['2', 'green']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 82: 4 blue, 8 green, 5 red; 14 red, 8 blue, 1 green; 11 red, 13 green
#  4 blue, 8 green, 5 red; 14 red, 8 blue, 1 green; 11 red, 13 green
# [' 4 blue, 8 green, 5 red', ' 14 red, 8 blue, 1 green', ' 11 red, 13 green']
# # ['4', 'blue']
# # ['8', 'green']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['14', 'red']
# # ['8', 'blue']
# # ['1', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['11', 'red']
# # ['13', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 83: 2 blue, 2 green, 10 red; 10 green, 4 red, 3 blue; 11 green, 14 red, 4 blue; 2 blue, 11 red; 3 blue, 1 green, 4 red
#  2 blue, 2 green, 10 red; 10 green, 4 red, 3 blue; 11 green, 14 red, 4 blue; 2 blue, 11 red; 3 blue, 1 green, 4 red
# [' 2 blue, 2 green, 10 red', ' 10 green, 4 red, 3 blue', ' 11 green, 14 red, 4 blue', ' 2 blue, 11 red', ' 3 blue, 1 green, 4 red']
# # ['2', 'blue']
# # ['2', 'green']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['4', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['11', 'green']
# # ['14', 'red']
# # ['4', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['11', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 84: 12 blue, 9 green, 10 red; 1 red, 6 green, 4 blue; 7 red, 3 green, 16 blue; 3 green, 3 blue
#  12 blue, 9 green, 10 red; 1 red, 6 green, 4 blue; 7 red, 3 green, 16 blue; 3 green, 3 blue
# [' 12 blue, 9 green, 10 red', ' 1 red, 6 green, 4 blue', ' 7 red, 3 green, 16 blue', ' 3 green, 3 blue']
# # ['12', 'blue']
# # ['9', 'green']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['6', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['3', 'green']
# # ['16', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 85: 2 red, 4 blue; 4 blue, 1 green, 6 red; 9 blue, 1 red; 1 green, 4 blue, 10 red; 5 green, 7 red, 17 blue
#  2 red, 4 blue; 4 blue, 1 green, 6 red; 9 blue, 1 red; 1 green, 4 blue, 10 red; 5 green, 7 red, 17 blue
# [' 2 red, 4 blue', ' 4 blue, 1 green, 6 red', ' 9 blue, 1 red', ' 1 green, 4 blue, 10 red', ' 5 green, 7 red, 17 blue']
# # ['2', 'red']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['1', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['4', 'blue']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['7', 'red']
# # ['17', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 86: 2 red, 3 blue, 1 green; 2 blue, 2 red, 2 green; 10 blue, 2 green; 5 green, 4 red, 6 blue
#  2 red, 3 blue, 1 green; 2 blue, 2 red, 2 green; 10 blue, 2 green; 5 green, 4 red, 6 blue
# [' 2 red, 3 blue, 1 green', ' 2 blue, 2 red, 2 green', ' 10 blue, 2 green', ' 5 green, 4 red, 6 blue']
# # ['2', 'red']
# # ['3', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['2', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['4', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 87: 1 red, 7 blue, 9 green; 3 green, 2 blue; 1 red, 4 blue, 10 green; 10 green, 7 blue, 1 red; 6 blue, 9 green; 9 blue, 7 green, 1 red
#  1 red, 7 blue, 9 green; 3 green, 2 blue; 1 red, 4 blue, 10 green; 10 green, 7 blue, 1 red; 6 blue, 9 green; 9 blue, 7 green, 1 red
# [' 1 red, 7 blue, 9 green', ' 3 green, 2 blue', ' 1 red, 4 blue, 10 green', ' 10 green, 7 blue, 1 red', ' 6 blue, 9 green', ' 9 blue, 7 green, 1 red']
# # ['1', 'red']
# # ['7', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['4', 'blue']
# # ['10', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['7', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 88: 1 blue, 14 red, 9 green; 4 green, 9 red; 8 green, 1 blue, 10 red
#  1 blue, 14 red, 9 green; 4 green, 9 red; 8 green, 1 blue, 10 red
# [' 1 blue, 14 red, 9 green', ' 4 green, 9 red', ' 8 green, 1 blue, 10 red']
# # ['1', 'blue']
# # ['14', 'red']
# # ['9', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['4', 'green']
# # ['9', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'green']
# # ['1', 'blue']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 89: 13 red, 1 green; 2 blue, 10 red; 1 green, 3 blue, 13 red; 1 green, 14 red, 3 blue; 2 green, 6 red; 1 green, 12 red
#  13 red, 1 green; 2 blue, 10 red; 1 green, 3 blue, 13 red; 1 green, 14 red, 3 blue; 2 green, 6 red; 1 green, 12 red
# [' 13 red, 1 green', ' 2 blue, 10 red', ' 1 green, 3 blue, 13 red', ' 1 green, 14 red, 3 blue', ' 2 green, 6 red', ' 1 green, 12 red']
# # ['13', 'red']
# # ['1', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'blue']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['3', 'blue']
# # ['13', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['14', 'red']
# # ['3', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['12', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 90: 1 red, 2 blue, 9 green; 1 blue, 3 red, 2 green; 10 green, 9 red; 1 red, 9 green, 4 blue; 3 blue, 13 green, 13 red
#  1 red, 2 blue, 9 green; 1 blue, 3 red, 2 green; 10 green, 9 red; 1 red, 9 green, 4 blue; 3 blue, 13 green, 13 red
# [' 1 red, 2 blue, 9 green', ' 1 blue, 3 red, 2 green', ' 10 green, 9 red', ' 1 red, 9 green, 4 blue', ' 3 blue, 13 green, 13 red']
# # ['1', 'red']
# # ['2', 'blue']
# # ['9', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['3', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['10', 'green']
# # ['9', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['9', 'green']
# # ['4', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['13', 'green']
# # ['13', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 91: 2 red, 8 green, 8 blue; 3 green, 2 red, 6 blue; 5 green, 4 red
#  2 red, 8 green, 8 blue; 3 green, 2 red, 6 blue; 5 green, 4 red
# [' 2 red, 8 green, 8 blue', ' 3 green, 2 red, 6 blue', ' 5 green, 4 red']
# # ['2', 'red']
# # ['8', 'green']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['2', 'red']
# # ['6', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['5', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 92: 8 green, 12 blue, 4 red; 7 red, 4 green; 4 blue, 7 green, 7 red; 7 blue, 5 green
#  8 green, 12 blue, 4 red; 7 red, 4 green; 4 blue, 7 green, 7 red; 7 blue, 5 green
# [' 8 green, 12 blue, 4 red', ' 7 red, 4 green', ' 4 blue, 7 green, 7 red', ' 7 blue, 5 green']
# # ['8', 'green']
# # ['12', 'blue']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'blue']
# # ['7', 'green']
# # ['7', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['5', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 93: 1 green, 1 red, 2 blue; 3 green, 1 red, 3 blue; 1 red, 8 blue; 1 green, 13 blue; 1 red, 4 blue, 4 green
#  1 green, 1 red, 2 blue; 3 green, 1 red, 3 blue; 1 red, 8 blue; 1 green, 13 blue; 1 red, 4 blue, 4 green
# [' 1 green, 1 red, 2 blue', ' 3 green, 1 red, 3 blue', ' 1 red, 8 blue', ' 1 green, 13 blue', ' 1 red, 4 blue, 4 green']
# # ['1', 'green']
# # ['1', 'red']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['1', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['8', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['13', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['4', 'blue']
# # ['4', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 94: 2 blue, 7 red, 17 green; 2 green, 1 blue, 5 red; 3 blue, 7 green, 1 red; 6 red, 1 blue, 1 green; 1 green, 1 blue, 1 red
#  2 blue, 7 red, 17 green; 2 green, 1 blue, 5 red; 3 blue, 7 green, 1 red; 6 red, 1 blue, 1 green; 1 green, 1 blue, 1 red
# [' 2 blue, 7 red, 17 green', ' 2 green, 1 blue, 5 red', ' 3 blue, 7 green, 1 red', ' 6 red, 1 blue, 1 green', ' 1 green, 1 blue, 1 red']
# # ['2', 'blue']
# # ['7', 'red']
# # ['17', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['1', 'blue']
# # ['5', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['1', 'blue']
# # ['1', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 95: 4 blue, 3 green, 4 red; 17 red, 2 blue; 6 blue, 16 green, 15 red; 7 blue, 17 green; 1 red, 3 green, 3 blue; 7 red, 14 green, 4 blue
#  4 blue, 3 green, 4 red; 17 red, 2 blue; 6 blue, 16 green, 15 red; 7 blue, 17 green; 1 red, 3 green, 3 blue; 7 red, 14 green, 4 blue
# [' 4 blue, 3 green, 4 red', ' 17 red, 2 blue', ' 6 blue, 16 green, 15 red', ' 7 blue, 17 green', ' 1 red, 3 green, 3 blue', ' 7 red, 14 green, 4 blue']
# # ['4', 'blue']
# # ['3', 'green']
# # ['4', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['17', 'red']
# # ['2', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['16', 'green']
# # ['15', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['7', 'blue']
# # ['17', 'green']
# NON POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['3', 'green']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'red']
# # ['14', 'green']
# # ['4', 'blue']
# NON POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 96: 6 red, 3 blue; 7 green, 5 blue, 10 red; 9 green, 1 blue; 6 blue, 1 red, 12 green; 3 blue, 10 green
#  6 red, 3 blue; 7 green, 5 blue, 10 red; 9 green, 1 blue; 6 blue, 1 red, 12 green; 3 blue, 10 green
# [' 6 red, 3 blue', ' 7 green, 5 blue, 10 red', ' 9 green, 1 blue', ' 6 blue, 1 red, 12 green', ' 3 blue, 10 green']
# # ['6', 'red']
# # ['3', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['7', 'green']
# # ['5', 'blue']
# # ['10', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'green']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['6', 'blue']
# # ['1', 'red']
# # ['12', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['10', 'green']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 97: 3 green, 1 red, 13 blue; 1 red, 8 green, 2 blue; 1 green, 2 blue, 2 red; 1 red, 4 green, 9 blue
#  3 green, 1 red, 13 blue; 1 red, 8 green, 2 blue; 1 green, 2 blue, 2 red; 1 red, 4 green, 9 blue
# [' 3 green, 1 red, 13 blue', ' 1 red, 8 green, 2 blue', ' 1 green, 2 blue, 2 red', ' 1 red, 4 green, 9 blue']
# # ['3', 'green']
# # ['1', 'red']
# # ['13', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['8', 'green']
# # ['2', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'red']
# # ['4', 'green']
# # ['9', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 98: 1 green, 8 red, 7 blue; 8 blue, 8 red, 3 green; 1 blue, 2 red; 4 red, 7 blue; 3 green, 3 blue, 3 red
#  1 green, 8 red, 7 blue; 8 blue, 8 red, 3 green; 1 blue, 2 red; 4 red, 7 blue; 3 green, 3 blue, 3 red
# [' 1 green, 8 red, 7 blue', ' 8 blue, 8 red, 3 green', ' 1 blue, 2 red', ' 4 red, 7 blue', ' 3 green, 3 blue, 3 red']
# # ['1', 'green']
# # ['8', 'red']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['8', 'blue']
# # ['8', 'red']
# # ['3', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['1', 'blue']
# # ['2', 'red']
# POSSIBLE SET IN CURRENT GAME
# # ['4', 'red']
# # ['7', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'green']
# # ['3', 'blue']
# # ['3', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Game 99: 9 blue, 14 red; 3 blue, 10 red, 5 green; 3 blue, 3 green, 6 red
#  9 blue, 14 red; 3 blue, 10 red, 5 green; 3 blue, 3 green, 6 red
# [' 9 blue, 14 red', ' 3 blue, 10 red, 5 green', ' 3 blue, 3 green, 6 red']
# # ['9', 'blue']
# # ['14', 'red']
# NON POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['10', 'red']
# # ['5', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['3', 'blue']
# # ['3', 'green']
# # ['6', 'red']
# POSSIBLE SET IN CURRENT GAME
# --- NON POSSIBLE GAME ---
# Game 100: 12 blue, 2 green; 2 green, 4 red, 13 blue; 9 blue, 1 red, 2 green; 2 green, 3 red, 1 blue
#  12 blue, 2 green; 2 green, 4 red, 13 blue; 9 blue, 1 red, 2 green; 2 green, 3 red, 1 blue
# [' 12 blue, 2 green', ' 2 green, 4 red, 13 blue', ' 9 blue, 1 red, 2 green', ' 2 green, 3 red, 1 blue']
# # ['12', 'blue']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['4', 'red']
# # ['13', 'blue']
# POSSIBLE SET IN CURRENT GAME
# # ['9', 'blue']
# # ['1', 'red']
# # ['2', 'green']
# POSSIBLE SET IN CURRENT GAME
# # ['2', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# POSSIBLE SET IN CURRENT GAME
# --- POSSIBLE GAME ---
# Sum of possible game IDs: 2449

# %% [markdown]
# ## Part 2

# %%
# *** [PART 2] ***
# ! As you continue your walk, the Elf poses a second question: In each game you played, what is the *fewest* number #   of cubes of EACH color that could have been in the bag to make the game possible?
# - For each game, find the *minimum* set of cubes that must have been present to make the game possible.
# - What is the sum of the power of these sets?
# - The power of a set of cubes = the number of red, green, and blue cubes multiplied together.
# --------------------------------------------------------------------------------------------------------------------
counter = 0 # counter var to keep track of the ID of EACH game
sumPowers = 0 # var to store the sum of the powers of ALL games

# TODO: Traverse through each game in the array list var 'arrFileData':
for game in arrFileData:
    counter = counter + 1 # increment counter for ID of CURRENT game

    # ! Create vars that store max value restriction for how many coloured cubes exist in the bag 
    #   for EACH set in EACH game
    max_red = 0
    max_green = 0
    max_blue = 0

    power = 0

    print(game)
    arrGameSplit = game.split(':')
    arrGameSets = arrGameSplit[1]
    print(arrGameSets)
    #arrGameSets = re.split('[,;]', arrGameSets) # multiple delimiters: '[xxx]' > e.g. '[,;:]'
    arrGameSets = arrGameSets.split(';')
    print(arrGameSets)

    # TODO: Traverse through EACH set in the CURRENT game
    for gameSet in arrGameSets:
        arrCubeValues = [] # var to store the number and colour of every cube drawn in EACH set for the CURRENT game

        # Separate the number of cubes drawn in the CURRENT set of the CURRENT game
        arrGameSet = gameSet.strip().split(',')
        #print("#", arrGameSet)

        # TODO: Traverse through EACH cube drawn in the CURRENT set of the CURRENT game
        for cube in arrGameSet:
            arrCubeValues = cube.strip().split(' ') # E.g ['3 red'] => ['3', 'red']
            print("#", arrCubeValues)

            # TODO: Check if 'red/green/blue' exists in the CURRENT value of the CURRENT set in the CURRENT game
            # - IF the respective colour exists, then set the respective number to the var holding the highest
            #   number of cubes for that particular colour in the CURRENT game
            if (arrCubeValues[1] == 'red') and (int(arrCubeValues[0]) > max_red):
                max_red = int(arrCubeValues[0])

            if (arrCubeValues[1] == 'green') and (int(arrCubeValues[0]) > max_green):
                max_green = int(arrCubeValues[0])

            if (arrCubeValues[1] == 'blue') and (int(arrCubeValues[0]) > max_blue):
                max_blue = int(arrCubeValues[0])

        #print('#red:', num_red, '#green:', num_green, '#blue:', num_blue)

    power = max_red * max_green * max_blue
    sumPowers = sumPowers + power

    print("--- Game", counter, ":", "min_red =", max_red, "min_green =", max_green, "min_blue =", max_blue, "---")
    print(" --- POWER =", power)

print("*Sum of powers of ALL games:", sumPowers)
# Out:
# Game 1: 13 red, 18 green; 5 green, 3 red, 5 blue; 5 green, 9 red, 6 blue; 3 blue, 3 green
#  13 red, 18 green; 5 green, 3 red, 5 blue; 5 green, 9 red, 6 blue; 3 blue, 3 green
# [' 13 red, 18 green', ' 5 green, 3 red, 5 blue', ' 5 green, 9 red, 6 blue', ' 3 blue, 3 green']
# # ['13', 'red']
# # ['18', 'green']
# # ['5', 'green']
# # ['3', 'red']
# # ['5', 'blue']
# # ['5', 'green']
# # ['9', 'red']
# # ['6', 'blue']
# # ['3', 'blue']
# # ['3', 'green']
# --- Game 1 : min_red = 13 min_green = 18 min_blue = 6 ---
#  --- POWER = 1404
# Game 2: 2 green, 3 blue, 5 red; 9 green, 4 red, 2 blue; 4 green, 3 blue; 2 blue, 3 red; 5 red, 3 blue, 9 green; 9 green, 5 red, 2 blue
#  2 green, 3 blue, 5 red; 9 green, 4 red, 2 blue; 4 green, 3 blue; 2 blue, 3 red; 5 red, 3 blue, 9 green; 9 green, 5 red, 2 blue
# [' 2 green, 3 blue, 5 red', ' 9 green, 4 red, 2 blue', ' 4 green, 3 blue', ' 2 blue, 3 red', ' 5 red, 3 blue, 9 green', ' 9 green, 5 red, 2 blue']
# # ['2', 'green']
# # ['3', 'blue']
# # ['5', 'red']
# # ['9', 'green']
# # ['4', 'red']
# # ['2', 'blue']
# # ['4', 'green']
# # ['3', 'blue']
# # ['2', 'blue']
# # ['3', 'red']
# # ['5', 'red']
# # ['3', 'blue']
# # ['9', 'green']
# # ['9', 'green']
# # ['5', 'red']
# # ['2', 'blue']
# --- Game 2 : min_red = 5 min_green = 9 min_blue = 3 ---
#  --- POWER = 135
# Game 3: 12 green, 3 red, 3 blue; 2 blue, 5 green, 2 red; 2 red, 3 blue, 11 green; 2 red, 8 green, 7 blue
#  12 green, 3 red, 3 blue; 2 blue, 5 green, 2 red; 2 red, 3 blue, 11 green; 2 red, 8 green, 7 blue
# [' 12 green, 3 red, 3 blue', ' 2 blue, 5 green, 2 red', ' 2 red, 3 blue, 11 green', ' 2 red, 8 green, 7 blue']
# # ['12', 'green']
# # ['3', 'red']
# # ['3', 'blue']
# # ['2', 'blue']
# # ['5', 'green']
# # ['2', 'red']
# # ['2', 'red']
# # ['3', 'blue']
# # ['11', 'green']
# # ['2', 'red']
# # ['8', 'green']
# # ['7', 'blue']
# --- Game 3 : min_red = 3 min_green = 12 min_blue = 7 ---
#  --- POWER = 252
# Game 4: 1 green, 2 blue; 7 green, 13 red; 2 blue, 5 green, 7 red; 6 green, 2 red
#  1 green, 2 blue; 7 green, 13 red; 2 blue, 5 green, 7 red; 6 green, 2 red
# [' 1 green, 2 blue', ' 7 green, 13 red', ' 2 blue, 5 green, 7 red', ' 6 green, 2 red']
# # ['1', 'green']
# # ['2', 'blue']
# # ['7', 'green']
# # ['13', 'red']
# # ['2', 'blue']
# # ['5', 'green']
# # ['7', 'red']
# # ['6', 'green']
# # ['2', 'red']
# --- Game 4 : min_red = 13 min_green = 7 min_blue = 2 ---
#  --- POWER = 182
# Game 5: 6 blue, 4 green; 8 blue, 7 green; 1 red, 10 blue
#  6 blue, 4 green; 8 blue, 7 green; 1 red, 10 blue
# [' 6 blue, 4 green', ' 8 blue, 7 green', ' 1 red, 10 blue']
# # ['6', 'blue']
# # ['4', 'green']
# # ['8', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# # ['10', 'blue']
# --- Game 5 : min_red = 1 min_green = 7 min_blue = 10 ---
#  --- POWER = 70
# Game 6: 4 red, 4 blue, 2 green; 8 green, 1 blue, 8 red; 9 green, 1 red, 3 blue
#  4 red, 4 blue, 2 green; 8 green, 1 blue, 8 red; 9 green, 1 red, 3 blue
# [' 4 red, 4 blue, 2 green', ' 8 green, 1 blue, 8 red', ' 9 green, 1 red, 3 blue']
# # ['4', 'red']
# # ['4', 'blue']
# # ['2', 'green']
# # ['8', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# # ['9', 'green']
# # ['1', 'red']
# # ['3', 'blue']
# --- Game 6 : min_red = 8 min_green = 9 min_blue = 4 ---
#  --- POWER = 288
# Game 7: 3 red, 12 green, 4 blue; 1 blue, 3 red, 6 green; 4 blue, 3 red, 15 green; 11 green, 2 blue, 2 red
#  3 red, 12 green, 4 blue; 1 blue, 3 red, 6 green; 4 blue, 3 red, 15 green; 11 green, 2 blue, 2 red
# [' 3 red, 12 green, 4 blue', ' 1 blue, 3 red, 6 green', ' 4 blue, 3 red, 15 green', ' 11 green, 2 blue, 2 red']
# # ['3', 'red']
# # ['12', 'green']
# # ['4', 'blue']
# # ['1', 'blue']
# # ['3', 'red']
# # ['6', 'green']
# # ['4', 'blue']
# # ['3', 'red']
# # ['15', 'green']
# # ['11', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# --- Game 7 : min_red = 3 min_green = 15 min_blue = 4 ---
#  --- POWER = 180
# Game 8: 13 blue, 7 green, 8 red; 5 green, 8 blue, 2 red; 5 red, 6 blue, 7 green; 6 green, 6 red, 3 blue; 7 blue, 8 red, 6 green
#  13 blue, 7 green, 8 red; 5 green, 8 blue, 2 red; 5 red, 6 blue, 7 green; 6 green, 6 red, 3 blue; 7 blue, 8 red, 6 green
# [' 13 blue, 7 green, 8 red', ' 5 green, 8 blue, 2 red', ' 5 red, 6 blue, 7 green', ' 6 green, 6 red, 3 blue', ' 7 blue, 8 red, 6 green']
# # ['13', 'blue']
# # ['7', 'green']
# # ['8', 'red']
# # ['5', 'green']
# # ['8', 'blue']
# # ['2', 'red']
# # ['5', 'red']
# # ['6', 'blue']
# # ['7', 'green']
# # ['6', 'green']
# # ['6', 'red']
# # ['3', 'blue']
# # ['7', 'blue']
# # ['8', 'red']
# # ['6', 'green']
# --- Game 8 : min_red = 8 min_green = 7 min_blue = 13 ---
#  --- POWER = 728
# Game 9: 4 blue, 1 green, 4 red; 16 red, 1 green, 7 blue; 11 red, 3 green, 7 blue
#  4 blue, 1 green, 4 red; 16 red, 1 green, 7 blue; 11 red, 3 green, 7 blue
# [' 4 blue, 1 green, 4 red', ' 16 red, 1 green, 7 blue', ' 11 red, 3 green, 7 blue']
# # ['4', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# # ['16', 'red']
# # ['1', 'green']
# # ['7', 'blue']
# # ['11', 'red']
# # ['3', 'green']
# # ['7', 'blue']
# --- Game 9 : min_red = 16 min_green = 3 min_blue = 7 ---
#  --- POWER = 336
# Game 10: 5 green, 1 red; 5 green, 3 blue; 1 red, 7 green, 3 blue; 1 blue, 6 green; 2 green, 4 blue
#  5 green, 1 red; 5 green, 3 blue; 1 red, 7 green, 3 blue; 1 blue, 6 green; 2 green, 4 blue
# [' 5 green, 1 red', ' 5 green, 3 blue', ' 1 red, 7 green, 3 blue', ' 1 blue, 6 green', ' 2 green, 4 blue']
# # ['5', 'green']
# # ['1', 'red']
# # ['5', 'green']
# # ['3', 'blue']
# # ['1', 'red']
# # ['7', 'green']
# # ['3', 'blue']
# # ['1', 'blue']
# # ['6', 'green']
# # ['2', 'green']
# # ['4', 'blue']
# --- Game 10 : min_red = 1 min_green = 7 min_blue = 4 ---
#  --- POWER = 28
# Game 11: 10 green, 2 blue, 2 red; 14 green, 1 blue, 3 red; 13 green; 3 green, 2 red; 3 red, 1 blue, 2 green; 1 red, 10 green, 2 blue
#  10 green, 2 blue, 2 red; 14 green, 1 blue, 3 red; 13 green; 3 green, 2 red; 3 red, 1 blue, 2 green; 1 red, 10 green, 2 blue
# [' 10 green, 2 blue, 2 red', ' 14 green, 1 blue, 3 red', ' 13 green', ' 3 green, 2 red', ' 3 red, 1 blue, 2 green', ' 1 red, 10 green, 2 blue']
# # ['10', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# # ['14', 'green']
# # ['1', 'blue']
# # ['3', 'red']
# # ['13', 'green']
# # ['3', 'green']
# # ['2', 'red']
# # ['3', 'red']
# # ['1', 'blue']
# # ['2', 'green']
# # ['1', 'red']
# # ['10', 'green']
# # ['2', 'blue']
# --- Game 11 : min_red = 3 min_green = 14 min_blue = 2 ---
#  --- POWER = 84
# Game 12: 9 green, 2 blue; 11 green, 1 blue; 2 red, 1 blue; 1 blue, 2 red, 3 green; 1 blue, 2 red, 3 green
#  9 green, 2 blue; 11 green, 1 blue; 2 red, 1 blue; 1 blue, 2 red, 3 green; 1 blue, 2 red, 3 green
# [' 9 green, 2 blue', ' 11 green, 1 blue', ' 2 red, 1 blue', ' 1 blue, 2 red, 3 green', ' 1 blue, 2 red, 3 green']
# # ['9', 'green']
# # ['2', 'blue']
# # ['11', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# # ['1', 'blue']
# # ['1', 'blue']
# # ['2', 'red']
# # ['3', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# # ['3', 'green']
# --- Game 12 : min_red = 2 min_green = 11 min_blue = 2 ---
#  --- POWER = 44
# Game 13: 11 blue, 3 red, 8 green; 9 red, 7 blue; 7 blue, 4 red
#  11 blue, 3 red, 8 green; 9 red, 7 blue; 7 blue, 4 red
# [' 11 blue, 3 red, 8 green', ' 9 red, 7 blue', ' 7 blue, 4 red']
# # ['11', 'blue']
# # ['3', 'red']
# # ['8', 'green']
# # ['9', 'red']
# # ['7', 'blue']
# # ['7', 'blue']
# # ['4', 'red']
# --- Game 13 : min_red = 9 min_green = 8 min_blue = 11 ---
#  --- POWER = 792
# Game 14: 17 blue, 2 red; 1 green, 13 blue, 1 red; 4 blue, 1 red, 4 green; 2 blue, 5 red, 13 green; 3 blue, 4 green, 6 red; 9 green, 14 blue, 6 red
#  17 blue, 2 red; 1 green, 13 blue, 1 red; 4 blue, 1 red, 4 green; 2 blue, 5 red, 13 green; 3 blue, 4 green, 6 red; 9 green, 14 blue, 6 red
# [' 17 blue, 2 red', ' 1 green, 13 blue, 1 red', ' 4 blue, 1 red, 4 green', ' 2 blue, 5 red, 13 green', ' 3 blue, 4 green, 6 red', ' 9 green, 14 blue, 6 red']
# # ['17', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# # ['13', 'blue']
# # ['1', 'red']
# # ['4', 'blue']
# # ['1', 'red']
# # ['4', 'green']
# # ['2', 'blue']
# # ['5', 'red']
# # ['13', 'green']
# # ['3', 'blue']
# # ['4', 'green']
# # ['6', 'red']
# # ['9', 'green']
# # ['14', 'blue']
# # ['6', 'red']
# --- Game 14 : min_red = 6 min_green = 13 min_blue = 17 ---
#  --- POWER = 1326
# Game 15: 7 green, 2 blue, 3 red; 4 red, 18 green; 8 green, 1 blue; 3 red, 15 green, 2 blue; 1 red, 15 green; 9 green, 3 red, 1 blue
#  7 green, 2 blue, 3 red; 4 red, 18 green; 8 green, 1 blue; 3 red, 15 green, 2 blue; 1 red, 15 green; 9 green, 3 red, 1 blue
# [' 7 green, 2 blue, 3 red', ' 4 red, 18 green', ' 8 green, 1 blue', ' 3 red, 15 green, 2 blue', ' 1 red, 15 green', ' 9 green, 3 red, 1 blue']
# # ['7', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# # ['4', 'red']
# # ['18', 'green']
# # ['8', 'green']
# # ['1', 'blue']
# # ['3', 'red']
# # ['15', 'green']
# # ['2', 'blue']
# # ['1', 'red']
# # ['15', 'green']
# # ['9', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# --- Game 15 : min_red = 4 min_green = 18 min_blue = 2 ---
#  --- POWER = 144
# Game 16: 10 red, 19 blue, 5 green; 12 red, 5 blue; 6 red, 3 green, 14 blue; 8 red, 10 blue, 6 green; 7 green, 10 red, 17 blue
#  10 red, 19 blue, 5 green; 12 red, 5 blue; 6 red, 3 green, 14 blue; 8 red, 10 blue, 6 green; 7 green, 10 red, 17 blue
# [' 10 red, 19 blue, 5 green', ' 12 red, 5 blue', ' 6 red, 3 green, 14 blue', ' 8 red, 10 blue, 6 green', ' 7 green, 10 red, 17 blue']
# # ['10', 'red']
# # ['19', 'blue']
# # ['5', 'green']
# # ['12', 'red']
# # ['5', 'blue']
# # ['6', 'red']
# # ['3', 'green']
# # ['14', 'blue']
# # ['8', 'red']
# # ['10', 'blue']
# # ['6', 'green']
# # ['7', 'green']
# # ['10', 'red']
# # ['17', 'blue']
# --- Game 16 : min_red = 12 min_green = 7 min_blue = 19 ---
#  --- POWER = 1596
# Game 17: 3 green, 3 red, 1 blue; 3 blue, 1 green, 2 red; 4 green, 3 red, 2 blue
#  3 green, 3 red, 1 blue; 3 blue, 1 green, 2 red; 4 green, 3 red, 2 blue
# [' 3 green, 3 red, 1 blue', ' 3 blue, 1 green, 2 red', ' 4 green, 3 red, 2 blue']
# # ['3', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# # ['3', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# # ['4', 'green']
# # ['3', 'red']
# # ['2', 'blue']
# --- Game 17 : min_red = 3 min_green = 4 min_blue = 3 ---
#  --- POWER = 36
# Game 18: 1 red, 2 blue; 1 green, 4 blue; 1 blue; 5 blue; 1 green, 3 red, 6 blue
#  1 red, 2 blue; 1 green, 4 blue; 1 blue; 5 blue; 1 green, 3 red, 6 blue
# [' 1 red, 2 blue', ' 1 green, 4 blue', ' 1 blue', ' 5 blue', ' 1 green, 3 red, 6 blue']
# # ['1', 'red']
# # ['2', 'blue']
# # ['1', 'green']
# # ['4', 'blue']
# # ['1', 'blue']
# # ['5', 'blue']
# # ['1', 'green']
# # ['3', 'red']
# # ['6', 'blue']
# --- Game 18 : min_red = 3 min_green = 1 min_blue = 6 ---
#  --- POWER = 18
# Game 19: 3 blue, 5 red, 8 green; 10 red, 6 blue, 11 green; 5 blue, 7 red, 8 green; 9 blue, 6 green, 5 red; 8 red, 12 green, 8 blue; 1 blue, 5 green, 10 red
#  3 blue, 5 red, 8 green; 10 red, 6 blue, 11 green; 5 blue, 7 red, 8 green; 9 blue, 6 green, 5 red; 8 red, 12 green, 8 blue; 1 blue, 5 green, 10 red
# [' 3 blue, 5 red, 8 green', ' 10 red, 6 blue, 11 green', ' 5 blue, 7 red, 8 green', ' 9 blue, 6 green, 5 red', ' 8 red, 12 green, 8 blue', ' 1 blue, 5 green, 10 red']
# # ['3', 'blue']
# # ['5', 'red']
# # ['8', 'green']
# # ['10', 'red']
# # ['6', 'blue']
# # ['11', 'green']
# # ['5', 'blue']
# # ['7', 'red']
# # ['8', 'green']
# # ['9', 'blue']
# # ['6', 'green']
# # ['5', 'red']
# # ['8', 'red']
# # ['12', 'green']
# # ['8', 'blue']
# # ['1', 'blue']
# # ['5', 'green']
# # ['10', 'red']
# --- Game 19 : min_red = 10 min_green = 12 min_blue = 9 ---
#  --- POWER = 1080
# Game 20: 16 blue, 2 green; 10 green, 1 red, 4 blue; 13 green, 5 red, 9 blue
#  16 blue, 2 green; 10 green, 1 red, 4 blue; 13 green, 5 red, 9 blue
# [' 16 blue, 2 green', ' 10 green, 1 red, 4 blue', ' 13 green, 5 red, 9 blue']
# # ['16', 'blue']
# # ['2', 'green']
# # ['10', 'green']
# # ['1', 'red']
# # ['4', 'blue']
# # ['13', 'green']
# # ['5', 'red']
# # ['9', 'blue']
# --- Game 20 : min_red = 5 min_green = 13 min_blue = 16 ---
#  --- POWER = 1040
# Game 21: 1 blue, 1 green, 14 red; 2 blue; 5 green, 1 blue; 2 green, 11 red; 2 red, 4 green; 2 green, 16 red
#  1 blue, 1 green, 14 red; 2 blue; 5 green, 1 blue; 2 green, 11 red; 2 red, 4 green; 2 green, 16 red
# [' 1 blue, 1 green, 14 red', ' 2 blue', ' 5 green, 1 blue', ' 2 green, 11 red', ' 2 red, 4 green', ' 2 green, 16 red']
# # ['1', 'blue']
# # ['1', 'green']
# # ['14', 'red']
# # ['2', 'blue']
# # ['5', 'green']
# # ['1', 'blue']
# # ['2', 'green']
# # ['11', 'red']
# # ['2', 'red']
# # ['4', 'green']
# # ['2', 'green']
# # ['16', 'red']
# --- Game 21 : min_red = 16 min_green = 5 min_blue = 2 ---
#  --- POWER = 160
# Game 22: 1 green, 10 red, 4 blue; 1 green, 4 blue, 8 red; 2 blue, 8 red; 4 green, 14 red; 1 blue, 5 red, 2 green
#  1 green, 10 red, 4 blue; 1 green, 4 blue, 8 red; 2 blue, 8 red; 4 green, 14 red; 1 blue, 5 red, 2 green
# [' 1 green, 10 red, 4 blue', ' 1 green, 4 blue, 8 red', ' 2 blue, 8 red', ' 4 green, 14 red', ' 1 blue, 5 red, 2 green']
# # ['1', 'green']
# # ['10', 'red']
# # ['4', 'blue']
# # ['1', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# # ['2', 'blue']
# # ['8', 'red']
# # ['4', 'green']
# # ['14', 'red']
# # ['1', 'blue']
# # ['5', 'red']
# # ['2', 'green']
# --- Game 22 : min_red = 14 min_green = 4 min_blue = 4 ---
#  --- POWER = 224
# Game 23: 17 green, 3 red, 16 blue; 9 green, 15 red; 3 red, 8 blue, 15 green
#  17 green, 3 red, 16 blue; 9 green, 15 red; 3 red, 8 blue, 15 green
# [' 17 green, 3 red, 16 blue', ' 9 green, 15 red', ' 3 red, 8 blue, 15 green']
# # ['17', 'green']
# # ['3', 'red']
# # ['16', 'blue']
# # ['9', 'green']
# # ['15', 'red']
# # ['3', 'red']
# # ['8', 'blue']
# # ['15', 'green']
# --- Game 23 : min_red = 15 min_green = 17 min_blue = 16 ---
#  --- POWER = 4080
# Game 24: 1 green, 1 blue; 2 blue, 1 green, 2 red; 3 green, 1 blue, 1 red; 3 blue, 1 red; 2 green, 5 blue
#  1 green, 1 blue; 2 blue, 1 green, 2 red; 3 green, 1 blue, 1 red; 3 blue, 1 red; 2 green, 5 blue
# [' 1 green, 1 blue', ' 2 blue, 1 green, 2 red', ' 3 green, 1 blue, 1 red', ' 3 blue, 1 red', ' 2 green, 5 blue']
# # ['1', 'green']
# # ['1', 'blue']
# # ['2', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# # ['3', 'green']
# # ['1', 'blue']
# # ['1', 'red']
# # ['3', 'blue']
# # ['1', 'red']
# # ['2', 'green']
# # ['5', 'blue']
# --- Game 24 : min_red = 2 min_green = 3 min_blue = 5 ---
#  --- POWER = 30
# Game 25: 11 red, 2 green; 7 red, 6 green; 10 red, 1 blue, 8 green; 8 green, 4 red; 6 green, 10 red; 2 blue, 7 red
#  11 red, 2 green; 7 red, 6 green; 10 red, 1 blue, 8 green; 8 green, 4 red; 6 green, 10 red; 2 blue, 7 red
# [' 11 red, 2 green', ' 7 red, 6 green', ' 10 red, 1 blue, 8 green', ' 8 green, 4 red', ' 6 green, 10 red', ' 2 blue, 7 red']
# # ['11', 'red']
# # ['2', 'green']
# # ['7', 'red']
# # ['6', 'green']
# # ['10', 'red']
# # ['1', 'blue']
# # ['8', 'green']
# # ['8', 'green']
# # ['4', 'red']
# # ['6', 'green']
# # ['10', 'red']
# # ['2', 'blue']
# # ['7', 'red']
# --- Game 25 : min_red = 11 min_green = 8 min_blue = 2 ---
#  --- POWER = 176
# Game 26: 2 green, 2 blue, 8 red; 1 blue, 1 red, 6 green; 9 red, 6 green, 2 blue
#  2 green, 2 blue, 8 red; 1 blue, 1 red, 6 green; 9 red, 6 green, 2 blue
# [' 2 green, 2 blue, 8 red', ' 1 blue, 1 red, 6 green', ' 9 red, 6 green, 2 blue']
# # ['2', 'green']
# # ['2', 'blue']
# # ['8', 'red']
# # ['1', 'blue']
# # ['1', 'red']
# # ['6', 'green']
# # ['9', 'red']
# # ['6', 'green']
# # ['2', 'blue']
# --- Game 26 : min_red = 9 min_green = 6 min_blue = 2 ---
#  --- POWER = 108
# Game 27: 5 red, 7 blue, 3 green; 3 blue, 1 red; 1 green, 1 red, 9 blue
#  5 red, 7 blue, 3 green; 3 blue, 1 red; 1 green, 1 red, 9 blue
# [' 5 red, 7 blue, 3 green', ' 3 blue, 1 red', ' 1 green, 1 red, 9 blue']
# # ['5', 'red']
# # ['7', 'blue']
# # ['3', 'green']
# # ['3', 'blue']
# # ['1', 'red']
# # ['1', 'green']
# # ['1', 'red']
# # ['9', 'blue']
# --- Game 27 : min_red = 5 min_green = 3 min_blue = 9 ---
#  --- POWER = 135
# Game 28: 17 red, 5 green, 10 blue; 3 red, 14 blue, 1 green; 11 blue, 11 green
#  17 red, 5 green, 10 blue; 3 red, 14 blue, 1 green; 11 blue, 11 green
# [' 17 red, 5 green, 10 blue', ' 3 red, 14 blue, 1 green', ' 11 blue, 11 green']
# # ['17', 'red']
# # ['5', 'green']
# # ['10', 'blue']
# # ['3', 'red']
# # ['14', 'blue']
# # ['1', 'green']
# # ['11', 'blue']
# # ['11', 'green']
# --- Game 28 : min_red = 17 min_green = 11 min_blue = 14 ---
#  --- POWER = 2618
# Game 29: 16 red, 4 green, 4 blue; 3 green, 5 blue, 11 red; 7 blue, 8 red, 1 green; 1 green, 10 red, 4 blue; 2 green, 4 blue, 8 red
#  16 red, 4 green, 4 blue; 3 green, 5 blue, 11 red; 7 blue, 8 red, 1 green; 1 green, 10 red, 4 blue; 2 green, 4 blue, 8 red
# [' 16 red, 4 green, 4 blue', ' 3 green, 5 blue, 11 red', ' 7 blue, 8 red, 1 green', ' 1 green, 10 red, 4 blue', ' 2 green, 4 blue, 8 red']
# # ['16', 'red']
# # ['4', 'green']
# # ['4', 'blue']
# # ['3', 'green']
# # ['5', 'blue']
# # ['11', 'red']
# # ['7', 'blue']
# # ['8', 'red']
# # ['1', 'green']
# # ['1', 'green']
# # ['10', 'red']
# # ['4', 'blue']
# # ['2', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# --- Game 29 : min_red = 16 min_green = 4 min_blue = 7 ---
#  --- POWER = 448
# Game 30: 3 green, 6 blue; 18 green, 3 blue; 14 green, 11 blue; 7 blue, 2 red, 17 green; 1 red, 12 green, 7 blue
#  3 green, 6 blue; 18 green, 3 blue; 14 green, 11 blue; 7 blue, 2 red, 17 green; 1 red, 12 green, 7 blue
# [' 3 green, 6 blue', ' 18 green, 3 blue', ' 14 green, 11 blue', ' 7 blue, 2 red, 17 green', ' 1 red, 12 green, 7 blue']
# # ['3', 'green']
# # ['6', 'blue']
# # ['18', 'green']
# # ['3', 'blue']
# # ['14', 'green']
# # ['11', 'blue']
# # ['7', 'blue']
# # ['2', 'red']
# # ['17', 'green']
# # ['1', 'red']
# # ['12', 'green']
# # ['7', 'blue']
# --- Game 30 : min_red = 2 min_green = 18 min_blue = 11 ---
#  --- POWER = 396
# Game 31: 11 red, 2 green, 3 blue; 10 green, 11 blue, 15 red; 12 green, 17 blue, 5 red; 5 green, 2 red, 12 blue; 13 blue, 13 green, 4 red
#  11 red, 2 green, 3 blue; 10 green, 11 blue, 15 red; 12 green, 17 blue, 5 red; 5 green, 2 red, 12 blue; 13 blue, 13 green, 4 red
# [' 11 red, 2 green, 3 blue', ' 10 green, 11 blue, 15 red', ' 12 green, 17 blue, 5 red', ' 5 green, 2 red, 12 blue', ' 13 blue, 13 green, 4 red']
# # ['11', 'red']
# # ['2', 'green']
# # ['3', 'blue']
# # ['10', 'green']
# # ['11', 'blue']
# # ['15', 'red']
# # ['12', 'green']
# # ['17', 'blue']
# # ['5', 'red']
# # ['5', 'green']
# # ['2', 'red']
# # ['12', 'blue']
# # ['13', 'blue']
# # ['13', 'green']
# # ['4', 'red']
# --- Game 31 : min_red = 15 min_green = 13 min_blue = 17 ---
#  --- POWER = 3315
# Game 32: 4 red, 2 blue, 5 green; 7 blue, 15 red; 11 blue, 4 green, 8 red
#  4 red, 2 blue, 5 green; 7 blue, 15 red; 11 blue, 4 green, 8 red
# [' 4 red, 2 blue, 5 green', ' 7 blue, 15 red', ' 11 blue, 4 green, 8 red']
# # ['4', 'red']
# # ['2', 'blue']
# # ['5', 'green']
# # ['7', 'blue']
# # ['15', 'red']
# # ['11', 'blue']
# # ['4', 'green']
# # ['8', 'red']
# --- Game 32 : min_red = 15 min_green = 5 min_blue = 11 ---
#  --- POWER = 825
# Game 33: 18 blue, 3 green, 3 red; 3 green, 6 red; 2 blue, 4 red, 1 green; 3 green, 5 red, 3 blue
#  18 blue, 3 green, 3 red; 3 green, 6 red; 2 blue, 4 red, 1 green; 3 green, 5 red, 3 blue
# [' 18 blue, 3 green, 3 red', ' 3 green, 6 red', ' 2 blue, 4 red, 1 green', ' 3 green, 5 red, 3 blue']
# # ['18', 'blue']
# # ['3', 'green']
# # ['3', 'red']
# # ['3', 'green']
# # ['6', 'red']
# # ['2', 'blue']
# # ['4', 'red']
# # ['1', 'green']
# # ['3', 'green']
# # ['5', 'red']
# # ['3', 'blue']
# --- Game 33 : min_red = 6 min_green = 3 min_blue = 18 ---
#  --- POWER = 324
# Game 34: 5 red, 2 blue, 16 green; 9 red, 10 blue, 3 green; 8 red, 10 green, 13 blue
#  5 red, 2 blue, 16 green; 9 red, 10 blue, 3 green; 8 red, 10 green, 13 blue
# [' 5 red, 2 blue, 16 green', ' 9 red, 10 blue, 3 green', ' 8 red, 10 green, 13 blue']
# # ['5', 'red']
# # ['2', 'blue']
# # ['16', 'green']
# # ['9', 'red']
# # ['10', 'blue']
# # ['3', 'green']
# # ['8', 'red']
# # ['10', 'green']
# # ['13', 'blue']
# --- Game 34 : min_red = 9 min_green = 16 min_blue = 13 ---
#  --- POWER = 1872
# Game 35: 7 blue, 5 red; 3 red, 1 blue; 4 blue, 7 red, 1 green; 4 red, 4 blue, 1 green; 3 blue, 7 red; 4 red, 1 green, 3 blue
#  7 blue, 5 red; 3 red, 1 blue; 4 blue, 7 red, 1 green; 4 red, 4 blue, 1 green; 3 blue, 7 red; 4 red, 1 green, 3 blue
# [' 7 blue, 5 red', ' 3 red, 1 blue', ' 4 blue, 7 red, 1 green', ' 4 red, 4 blue, 1 green', ' 3 blue, 7 red', ' 4 red, 1 green, 3 blue']
# # ['7', 'blue']
# # ['5', 'red']
# # ['3', 'red']
# # ['1', 'blue']
# # ['4', 'blue']
# # ['7', 'red']
# # ['1', 'green']
# # ['4', 'red']
# # ['4', 'blue']
# # ['1', 'green']
# # ['3', 'blue']
# # ['7', 'red']
# # ['4', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# --- Game 35 : min_red = 7 min_green = 1 min_blue = 7 ---
#  --- POWER = 49
# Game 36: 14 blue; 10 blue, 1 green; 10 blue, 4 green; 4 blue, 1 green, 1 red; 1 red, 6 blue, 4 green; 1 green, 1 red, 11 blue
#  14 blue; 10 blue, 1 green; 10 blue, 4 green; 4 blue, 1 green, 1 red; 1 red, 6 blue, 4 green; 1 green, 1 red, 11 blue
# [' 14 blue', ' 10 blue, 1 green', ' 10 blue, 4 green', ' 4 blue, 1 green, 1 red', ' 1 red, 6 blue, 4 green', ' 1 green, 1 red, 11 blue']
# # ['14', 'blue']
# # ['10', 'blue']
# # ['1', 'green']
# # ['10', 'blue']
# # ['4', 'green']
# # ['4', 'blue']
# # ['1', 'green']
# # ['1', 'red']
# # ['1', 'red']
# # ['6', 'blue']
# # ['4', 'green']
# # ['1', 'green']
# # ['1', 'red']
# # ['11', 'blue']
# --- Game 36 : min_red = 1 min_green = 4 min_blue = 14 ---
#  --- POWER = 56
# Game 37: 8 red, 13 green, 5 blue; 11 red, 16 green, 8 blue; 2 green, 10 blue, 11 red
#  8 red, 13 green, 5 blue; 11 red, 16 green, 8 blue; 2 green, 10 blue, 11 red
# [' 8 red, 13 green, 5 blue', ' 11 red, 16 green, 8 blue', ' 2 green, 10 blue, 11 red']
# # ['8', 'red']
# # ['13', 'green']
# # ['5', 'blue']
# # ['11', 'red']
# # ['16', 'green']
# # ['8', 'blue']
# # ['2', 'green']
# # ['10', 'blue']
# # ['11', 'red']
# --- Game 37 : min_red = 11 min_green = 16 min_blue = 10 ---
#  --- POWER = 1760
# Game 38: 2 red, 1 blue, 10 green; 7 red, 6 blue, 14 green; 18 red, 1 blue, 5 green; 5 green, 5 blue, 13 red; 14 red, 5 green; 15 green, 13 red, 2 blue
#  2 red, 1 blue, 10 green; 7 red, 6 blue, 14 green; 18 red, 1 blue, 5 green; 5 green, 5 blue, 13 red; 14 red, 5 green; 15 green, 13 red, 2 blue
# [' 2 red, 1 blue, 10 green', ' 7 red, 6 blue, 14 green', ' 18 red, 1 blue, 5 green', ' 5 green, 5 blue, 13 red', ' 14 red, 5 green', ' 15 green, 13 red, 2 blue']
# # ['2', 'red']
# # ['1', 'blue']
# # ['10', 'green']
# # ['7', 'red']
# # ['6', 'blue']
# # ['14', 'green']
# # ['18', 'red']
# # ['1', 'blue']
# # ['5', 'green']
# # ['5', 'green']
# # ['5', 'blue']
# # ['13', 'red']
# # ['14', 'red']
# # ['5', 'green']
# # ['15', 'green']
# # ['13', 'red']
# # ['2', 'blue']
# --- Game 38 : min_red = 18 min_green = 15 min_blue = 6 ---
#  --- POWER = 1620
# Game 39: 1 blue, 5 red; 9 red, 9 green; 4 blue, 10 green, 4 red; 3 green, 11 red, 1 blue; 2 green, 11 red, 4 blue
#  1 blue, 5 red; 9 red, 9 green; 4 blue, 10 green, 4 red; 3 green, 11 red, 1 blue; 2 green, 11 red, 4 blue
# [' 1 blue, 5 red', ' 9 red, 9 green', ' 4 blue, 10 green, 4 red', ' 3 green, 11 red, 1 blue', ' 2 green, 11 red, 4 blue']
# # ['1', 'blue']
# # ['5', 'red']
# # ['9', 'red']
# # ['9', 'green']
# # ['4', 'blue']
# # ['10', 'green']
# # ['4', 'red']
# # ['3', 'green']
# # ['11', 'red']
# # ['1', 'blue']
# # ['2', 'green']
# # ['11', 'red']
# # ['4', 'blue']
# --- Game 39 : min_red = 11 min_green = 10 min_blue = 4 ---
#  --- POWER = 440
# Game 40: 9 blue, 4 green; 12 green, 1 red; 2 red, 15 green, 10 blue
#  9 blue, 4 green; 12 green, 1 red; 2 red, 15 green, 10 blue
# [' 9 blue, 4 green', ' 12 green, 1 red', ' 2 red, 15 green, 10 blue']
# # ['9', 'blue']
# # ['4', 'green']
# # ['12', 'green']
# # ['1', 'red']
# # ['2', 'red']
# # ['15', 'green']
# # ['10', 'blue']
# --- Game 40 : min_red = 2 min_green = 15 min_blue = 10 ---
#  --- POWER = 300
# Game 41: 1 blue, 14 red, 12 green; 16 green, 2 blue, 3 red; 6 green, 9 red
#  1 blue, 14 red, 12 green; 16 green, 2 blue, 3 red; 6 green, 9 red
# [' 1 blue, 14 red, 12 green', ' 16 green, 2 blue, 3 red', ' 6 green, 9 red']
# # ['1', 'blue']
# # ['14', 'red']
# # ['12', 'green']
# # ['16', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# # ['6', 'green']
# # ['9', 'red']
# --- Game 41 : min_red = 14 min_green = 16 min_blue = 2 ---
#  --- POWER = 448
# Game 42: 4 green, 13 red, 9 blue; 9 green, 9 red, 4 blue; 7 blue, 10 red, 9 green; 4 green, 18 blue, 14 red; 9 blue, 7 green, 2 red
#  4 green, 13 red, 9 blue; 9 green, 9 red, 4 blue; 7 blue, 10 red, 9 green; 4 green, 18 blue, 14 red; 9 blue, 7 green, 2 red
# [' 4 green, 13 red, 9 blue', ' 9 green, 9 red, 4 blue', ' 7 blue, 10 red, 9 green', ' 4 green, 18 blue, 14 red', ' 9 blue, 7 green, 2 red']
# # ['4', 'green']
# # ['13', 'red']
# # ['9', 'blue']
# # ['9', 'green']
# # ['9', 'red']
# # ['4', 'blue']
# # ['7', 'blue']
# # ['10', 'red']
# # ['9', 'green']
# # ['4', 'green']
# # ['18', 'blue']
# # ['14', 'red']
# # ['9', 'blue']
# # ['7', 'green']
# # ['2', 'red']
# --- Game 42 : min_red = 14 min_green = 9 min_blue = 18 ---
#  --- POWER = 2268
# Game 43: 7 red, 6 blue; 4 green; 3 red, 6 green; 7 blue, 6 green, 8 red; 9 green, 7 blue, 7 red; 5 blue, 5 green, 6 red
#  7 red, 6 blue; 4 green; 3 red, 6 green; 7 blue, 6 green, 8 red; 9 green, 7 blue, 7 red; 5 blue, 5 green, 6 red
# [' 7 red, 6 blue', ' 4 green', ' 3 red, 6 green', ' 7 blue, 6 green, 8 red', ' 9 green, 7 blue, 7 red', ' 5 blue, 5 green, 6 red']
# # ['7', 'red']
# # ['6', 'blue']
# # ['4', 'green']
# # ['3', 'red']
# # ['6', 'green']
# # ['7', 'blue']
# # ['6', 'green']
# # ['8', 'red']
# # ['9', 'green']
# # ['7', 'blue']
# # ['7', 'red']
# # ['5', 'blue']
# # ['5', 'green']
# # ['6', 'red']
# --- Game 43 : min_red = 8 min_green = 9 min_blue = 7 ---
#  --- POWER = 504
# Game 44: 5 red, 8 blue; 2 red, 5 green; 6 green, 11 blue, 2 red; 1 green, 1 blue, 2 red
#  5 red, 8 blue; 2 red, 5 green; 6 green, 11 blue, 2 red; 1 green, 1 blue, 2 red
# [' 5 red, 8 blue', ' 2 red, 5 green', ' 6 green, 11 blue, 2 red', ' 1 green, 1 blue, 2 red']
# # ['5', 'red']
# # ['8', 'blue']
# # ['2', 'red']
# # ['5', 'green']
# # ['6', 'green']
# # ['11', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# --- Game 44 : min_red = 5 min_green = 6 min_blue = 11 ---
#  --- POWER = 330
# Game 45: 3 blue, 7 green, 1 red; 5 red, 1 blue; 2 blue, 3 red; 8 green, 5 red
#  3 blue, 7 green, 1 red; 5 red, 1 blue; 2 blue, 3 red; 8 green, 5 red
# [' 3 blue, 7 green, 1 red', ' 5 red, 1 blue', ' 2 blue, 3 red', ' 8 green, 5 red']
# # ['3', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# # ['5', 'red']
# # ['1', 'blue']
# # ['2', 'blue']
# # ['3', 'red']
# # ['8', 'green']
# # ['5', 'red']
# --- Game 45 : min_red = 5 min_green = 8 min_blue = 3 ---
#  --- POWER = 120
# Game 46: 4 red, 4 blue, 17 green; 1 blue, 5 green, 1 red; 1 red, 1 blue, 7 green; 18 green, 7 blue
#  4 red, 4 blue, 17 green; 1 blue, 5 green, 1 red; 1 red, 1 blue, 7 green; 18 green, 7 blue
# [' 4 red, 4 blue, 17 green', ' 1 blue, 5 green, 1 red', ' 1 red, 1 blue, 7 green', ' 18 green, 7 blue']
# # ['4', 'red']
# # ['4', 'blue']
# # ['17', 'green']
# # ['1', 'blue']
# # ['5', 'green']
# # ['1', 'red']
# # ['1', 'red']
# # ['1', 'blue']
# # ['7', 'green']
# # ['18', 'green']
# # ['7', 'blue']
# --- Game 46 : min_red = 4 min_green = 18 min_blue = 7 ---
#  --- POWER = 504
# Game 47: 14 red, 3 green, 2 blue; 4 green, 4 red, 2 blue; 13 red, 1 blue
#  14 red, 3 green, 2 blue; 4 green, 4 red, 2 blue; 13 red, 1 blue
# [' 14 red, 3 green, 2 blue', ' 4 green, 4 red, 2 blue', ' 13 red, 1 blue']
# # ['14', 'red']
# # ['3', 'green']
# # ['2', 'blue']
# # ['4', 'green']
# # ['4', 'red']
# # ['2', 'blue']
# # ['13', 'red']
# # ['1', 'blue']
# --- Game 47 : min_red = 14 min_green = 4 min_blue = 2 ---
#  --- POWER = 112
# Game 48: 5 red, 12 blue, 2 green; 3 blue, 1 red, 2 green; 10 blue, 7 red
#  5 red, 12 blue, 2 green; 3 blue, 1 red, 2 green; 10 blue, 7 red
# [' 5 red, 12 blue, 2 green', ' 3 blue, 1 red, 2 green', ' 10 blue, 7 red']
# # ['5', 'red']
# # ['12', 'blue']
# # ['2', 'green']
# # ['3', 'blue']
# # ['1', 'red']
# # ['2', 'green']
# # ['10', 'blue']
# # ['7', 'red']
# --- Game 48 : min_red = 7 min_green = 2 min_blue = 12 ---
#  --- POWER = 168
# Game 49: 6 blue, 11 red; 11 red, 17 blue, 11 green; 16 blue, 12 green, 6 red
#  6 blue, 11 red; 11 red, 17 blue, 11 green; 16 blue, 12 green, 6 red
# [' 6 blue, 11 red', ' 11 red, 17 blue, 11 green', ' 16 blue, 12 green, 6 red']
# # ['6', 'blue']
# # ['11', 'red']
# # ['11', 'red']
# # ['17', 'blue']
# # ['11', 'green']
# # ['16', 'blue']
# # ['12', 'green']
# # ['6', 'red']
# --- Game 49 : min_red = 11 min_green = 12 min_blue = 17 ---
#  --- POWER = 2244
# Game 50: 12 blue, 3 green, 1 red; 3 green, 10 blue, 3 red; 11 blue, 3 red
#  12 blue, 3 green, 1 red; 3 green, 10 blue, 3 red; 11 blue, 3 red
# [' 12 blue, 3 green, 1 red', ' 3 green, 10 blue, 3 red', ' 11 blue, 3 red']
# # ['12', 'blue']
# # ['3', 'green']
# # ['1', 'red']
# # ['3', 'green']
# # ['10', 'blue']
# # ['3', 'red']
# # ['11', 'blue']
# # ['3', 'red']
# --- Game 50 : min_red = 3 min_green = 3 min_blue = 12 ---
#  --- POWER = 108
# Game 51: 12 green, 1 blue, 8 red; 6 blue, 1 green, 9 red; 17 red, 5 blue; 7 blue, 9 green, 9 red; 13 green, 10 red, 2 blue
#  12 green, 1 blue, 8 red; 6 blue, 1 green, 9 red; 17 red, 5 blue; 7 blue, 9 green, 9 red; 13 green, 10 red, 2 blue
# [' 12 green, 1 blue, 8 red', ' 6 blue, 1 green, 9 red', ' 17 red, 5 blue', ' 7 blue, 9 green, 9 red', ' 13 green, 10 red, 2 blue']
# # ['12', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# # ['6', 'blue']
# # ['1', 'green']
# # ['9', 'red']
# # ['17', 'red']
# # ['5', 'blue']
# # ['7', 'blue']
# # ['9', 'green']
# # ['9', 'red']
# # ['13', 'green']
# # ['10', 'red']
# # ['2', 'blue']
# --- Game 51 : min_red = 17 min_green = 13 min_blue = 7 ---
#  --- POWER = 1547
# Game 52: 5 blue, 1 green; 1 red, 1 green, 3 blue; 8 blue, 1 green; 1 green, 7 blue; 3 blue; 1 red, 6 blue
#  5 blue, 1 green; 1 red, 1 green, 3 blue; 8 blue, 1 green; 1 green, 7 blue; 3 blue; 1 red, 6 blue
# [' 5 blue, 1 green', ' 1 red, 1 green, 3 blue', ' 8 blue, 1 green', ' 1 green, 7 blue', ' 3 blue', ' 1 red, 6 blue']
# # ['5', 'blue']
# # ['1', 'green']
# # ['1', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# # ['8', 'blue']
# # ['1', 'green']
# # ['1', 'green']
# # ['7', 'blue']
# # ['3', 'blue']
# # ['1', 'red']
# # ['6', 'blue']
# --- Game 52 : min_red = 1 min_green = 1 min_blue = 8 ---
#  --- POWER = 8
# Game 53: 11 green, 5 red; 16 green, 6 blue; 4 red, 19 green, 4 blue
#  11 green, 5 red; 16 green, 6 blue; 4 red, 19 green, 4 blue
# [' 11 green, 5 red', ' 16 green, 6 blue', ' 4 red, 19 green, 4 blue']
# # ['11', 'green']
# # ['5', 'red']
# # ['16', 'green']
# # ['6', 'blue']
# # ['4', 'red']
# # ['19', 'green']
# # ['4', 'blue']
# --- Game 53 : min_red = 5 min_green = 19 min_blue = 6 ---
#  --- POWER = 570
# Game 54: 6 green, 4 blue, 8 red; 7 red, 6 green, 5 blue; 5 blue, 4 red; 5 blue, 14 red
#  6 green, 4 blue, 8 red; 7 red, 6 green, 5 blue; 5 blue, 4 red; 5 blue, 14 red
# [' 6 green, 4 blue, 8 red', ' 7 red, 6 green, 5 blue', ' 5 blue, 4 red', ' 5 blue, 14 red']
# # ['6', 'green']
# # ['4', 'blue']
# # ['8', 'red']
# # ['7', 'red']
# # ['6', 'green']
# # ['5', 'blue']
# # ['5', 'blue']
# # ['4', 'red']
# # ['5', 'blue']
# # ['14', 'red']
# --- Game 54 : min_red = 14 min_green = 6 min_blue = 5 ---
#  --- POWER = 420
# Game 55: 11 blue, 1 green; 2 red, 5 blue, 1 green; 10 blue, 1 green; 11 blue; 2 green, 2 red, 5 blue
#  11 blue, 1 green; 2 red, 5 blue, 1 green; 10 blue, 1 green; 11 blue; 2 green, 2 red, 5 blue
# [' 11 blue, 1 green', ' 2 red, 5 blue, 1 green', ' 10 blue, 1 green', ' 11 blue', ' 2 green, 2 red, 5 blue']
# # ['11', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# # ['5', 'blue']
# # ['1', 'green']
# # ['10', 'blue']
# # ['1', 'green']
# # ['11', 'blue']
# # ['2', 'green']
# # ['2', 'red']
# # ['5', 'blue']
# --- Game 55 : min_red = 2 min_green = 2 min_blue = 11 ---
#  --- POWER = 44
# Game 56: 1 red, 9 blue, 1 green; 2 red, 8 blue; 1 green, 9 blue, 10 red; 5 blue, 1 green; 15 blue, 1 red; 12 blue, 4 red
#  1 red, 9 blue, 1 green; 2 red, 8 blue; 1 green, 9 blue, 10 red; 5 blue, 1 green; 15 blue, 1 red; 12 blue, 4 red
# [' 1 red, 9 blue, 1 green', ' 2 red, 8 blue', ' 1 green, 9 blue, 10 red', ' 5 blue, 1 green', ' 15 blue, 1 red', ' 12 blue, 4 red']
# # ['1', 'red']
# # ['9', 'blue']
# # ['1', 'green']
# # ['2', 'red']
# # ['8', 'blue']
# # ['1', 'green']
# # ['9', 'blue']
# # ['10', 'red']
# # ['5', 'blue']
# # ['1', 'green']
# # ['15', 'blue']
# # ['1', 'red']
# # ['12', 'blue']
# # ['4', 'red']
# --- Game 56 : min_red = 10 min_green = 1 min_blue = 15 ---
#  --- POWER = 150
# Game 57: 1 green, 17 blue; 10 blue, 2 green; 2 red, 16 blue; 6 green, 15 blue; 5 green; 2 red, 1 green
#  1 green, 17 blue; 10 blue, 2 green; 2 red, 16 blue; 6 green, 15 blue; 5 green; 2 red, 1 green
# [' 1 green, 17 blue', ' 10 blue, 2 green', ' 2 red, 16 blue', ' 6 green, 15 blue', ' 5 green', ' 2 red, 1 green']
# # ['1', 'green']
# # ['17', 'blue']
# # ['10', 'blue']
# # ['2', 'green']
# # ['2', 'red']
# # ['16', 'blue']
# # ['6', 'green']
# # ['15', 'blue']
# # ['5', 'green']
# # ['2', 'red']
# # ['1', 'green']
# --- Game 57 : min_red = 2 min_green = 6 min_blue = 17 ---
#  --- POWER = 204
# Game 58: 2 blue, 4 green, 2 red; 5 blue; 5 red, 3 green, 2 blue; 5 red, 2 green, 5 blue; 7 green, 3 red, 4 blue; 4 red
#  2 blue, 4 green, 2 red; 5 blue; 5 red, 3 green, 2 blue; 5 red, 2 green, 5 blue; 7 green, 3 red, 4 blue; 4 red
# [' 2 blue, 4 green, 2 red', ' 5 blue', ' 5 red, 3 green, 2 blue', ' 5 red, 2 green, 5 blue', ' 7 green, 3 red, 4 blue', ' 4 red']
# # ['2', 'blue']
# # ['4', 'green']
# # ['2', 'red']
# # ['5', 'blue']
# # ['5', 'red']
# # ['3', 'green']
# # ['2', 'blue']
# # ['5', 'red']
# # ['2', 'green']
# # ['5', 'blue']
# # ['7', 'green']
# # ['3', 'red']
# # ['4', 'blue']
# # ['4', 'red']
# --- Game 58 : min_red = 5 min_green = 7 min_blue = 5 ---
#  --- POWER = 175
# Game 59: 8 blue, 2 red, 2 green; 15 blue, 1 green, 4 red; 9 blue, 1 red; 3 green, 5 red, 5 blue
#  8 blue, 2 red, 2 green; 15 blue, 1 green, 4 red; 9 blue, 1 red; 3 green, 5 red, 5 blue
# [' 8 blue, 2 red, 2 green', ' 15 blue, 1 green, 4 red', ' 9 blue, 1 red', ' 3 green, 5 red, 5 blue']
# # ['8', 'blue']
# # ['2', 'red']
# # ['2', 'green']
# # ['15', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# # ['9', 'blue']
# # ['1', 'red']
# # ['3', 'green']
# # ['5', 'red']
# # ['5', 'blue']
# --- Game 59 : min_red = 5 min_green = 3 min_blue = 15 ---
#  --- POWER = 225
# Game 60: 3 red, 2 blue, 6 green; 1 red, 5 green; 2 blue, 10 green; 6 green, 2 red
#  3 red, 2 blue, 6 green; 1 red, 5 green; 2 blue, 10 green; 6 green, 2 red
# [' 3 red, 2 blue, 6 green', ' 1 red, 5 green', ' 2 blue, 10 green', ' 6 green, 2 red']
# # ['3', 'red']
# # ['2', 'blue']
# # ['6', 'green']
# # ['1', 'red']
# # ['5', 'green']
# # ['2', 'blue']
# # ['10', 'green']
# # ['6', 'green']
# # ['2', 'red']
# --- Game 60 : min_red = 3 min_green = 10 min_blue = 2 ---
#  --- POWER = 60
# Game 61: 6 green, 4 blue; 1 red, 4 blue, 15 green; 1 blue, 16 green, 3 red; 6 red, 12 green, 2 blue; 3 red, 14 green, 1 blue; 3 red, 2 blue, 9 green
#  6 green, 4 blue; 1 red, 4 blue, 15 green; 1 blue, 16 green, 3 red; 6 red, 12 green, 2 blue; 3 red, 14 green, 1 blue; 3 red, 2 blue, 9 green
# [' 6 green, 4 blue', ' 1 red, 4 blue, 15 green', ' 1 blue, 16 green, 3 red', ' 6 red, 12 green, 2 blue', ' 3 red, 14 green, 1 blue', ' 3 red, 2 blue, 9 green']
# # ['6', 'green']
# # ['4', 'blue']
# # ['1', 'red']
# # ['4', 'blue']
# # ['15', 'green']
# # ['1', 'blue']
# # ['16', 'green']
# # ['3', 'red']
# # ['6', 'red']
# # ['12', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# # ['14', 'green']
# # ['1', 'blue']
# # ['3', 'red']
# # ['2', 'blue']
# # ['9', 'green']
# --- Game 61 : min_red = 6 min_green = 16 min_blue = 4 ---
#  --- POWER = 384
# Game 62: 1 green, 2 red; 4 red; 1 green, 4 red, 1 blue; 1 red, 1 blue, 1 green
#  1 green, 2 red; 4 red; 1 green, 4 red, 1 blue; 1 red, 1 blue, 1 green
# [' 1 green, 2 red', ' 4 red', ' 1 green, 4 red, 1 blue', ' 1 red, 1 blue, 1 green']
# # ['1', 'green']
# # ['2', 'red']
# # ['4', 'red']
# # ['1', 'green']
# # ['4', 'red']
# # ['1', 'blue']
# # ['1', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# --- Game 62 : min_red = 4 min_green = 1 min_blue = 1 ---
#  --- POWER = 4
# Game 63: 8 green, 4 red, 4 blue; 5 red, 4 blue, 8 green; 3 green, 1 blue
#  8 green, 4 red, 4 blue; 5 red, 4 blue, 8 green; 3 green, 1 blue
# [' 8 green, 4 red, 4 blue', ' 5 red, 4 blue, 8 green', ' 3 green, 1 blue']
# # ['8', 'green']
# # ['4', 'red']
# # ['4', 'blue']
# # ['5', 'red']
# # ['4', 'blue']
# # ['8', 'green']
# # ['3', 'green']
# # ['1', 'blue']
# --- Game 63 : min_red = 5 min_green = 8 min_blue = 4 ---
#  --- POWER = 160
# Game 64: 5 blue, 2 green, 5 red; 3 green, 2 blue, 1 red; 6 blue, 2 red, 1 green; 2 green, 2 blue, 3 red; 3 blue, 1 red
#  5 blue, 2 green, 5 red; 3 green, 2 blue, 1 red; 6 blue, 2 red, 1 green; 2 green, 2 blue, 3 red; 3 blue, 1 red
# [' 5 blue, 2 green, 5 red', ' 3 green, 2 blue, 1 red', ' 6 blue, 2 red, 1 green', ' 2 green, 2 blue, 3 red', ' 3 blue, 1 red']
# # ['5', 'blue']
# # ['2', 'green']
# # ['5', 'red']
# # ['3', 'green']
# # ['2', 'blue']
# # ['1', 'red']
# # ['6', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# # ['2', 'green']
# # ['2', 'blue']
# # ['3', 'red']
# # ['3', 'blue']
# # ['1', 'red']
# --- Game 64 : min_red = 5 min_green = 3 min_blue = 6 ---
#  --- POWER = 90
# Game 65: 2 red, 7 green, 5 blue; 8 blue, 3 green, 4 red; 1 red, 6 green, 1 blue
#  2 red, 7 green, 5 blue; 8 blue, 3 green, 4 red; 1 red, 6 green, 1 blue
# [' 2 red, 7 green, 5 blue', ' 8 blue, 3 green, 4 red', ' 1 red, 6 green, 1 blue']
# # ['2', 'red']
# # ['7', 'green']
# # ['5', 'blue']
# # ['8', 'blue']
# # ['3', 'green']
# # ['4', 'red']
# # ['1', 'red']
# # ['6', 'green']
# # ['1', 'blue']
# --- Game 65 : min_red = 4 min_green = 7 min_blue = 8 ---
#  --- POWER = 224
# Game 66: 1 green, 6 red; 5 red, 1 green, 1 blue; 4 red, 1 blue, 1 green; 1 blue, 2 red, 1 green; 1 blue, 5 red; 1 blue, 8 red
#  1 green, 6 red; 5 red, 1 green, 1 blue; 4 red, 1 blue, 1 green; 1 blue, 2 red, 1 green; 1 blue, 5 red; 1 blue, 8 red
# [' 1 green, 6 red', ' 5 red, 1 green, 1 blue', ' 4 red, 1 blue, 1 green', ' 1 blue, 2 red, 1 green', ' 1 blue, 5 red', ' 1 blue, 8 red']
# # ['1', 'green']
# # ['6', 'red']
# # ['5', 'red']
# # ['1', 'green']
# # ['1', 'blue']
# # ['4', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# # ['1', 'green']
# # ['1', 'blue']
# # ['5', 'red']
# # ['1', 'blue']
# # ['8', 'red']
# --- Game 66 : min_red = 8 min_green = 1 min_blue = 1 ---
#  --- POWER = 8
# Game 67: 6 red, 8 blue, 8 green; 5 green, 2 red, 10 blue; 4 red, 1 green; 7 blue, 2 green
#  6 red, 8 blue, 8 green; 5 green, 2 red, 10 blue; 4 red, 1 green; 7 blue, 2 green
# [' 6 red, 8 blue, 8 green', ' 5 green, 2 red, 10 blue', ' 4 red, 1 green', ' 7 blue, 2 green']
# # ['6', 'red']
# # ['8', 'blue']
# # ['8', 'green']
# # ['5', 'green']
# # ['2', 'red']
# # ['10', 'blue']
# # ['4', 'red']
# # ['1', 'green']
# # ['7', 'blue']
# # ['2', 'green']
# --- Game 67 : min_red = 6 min_green = 8 min_blue = 10 ---
#  --- POWER = 480
# Game 68: 7 green, 9 red, 15 blue; 4 green, 6 red, 3 blue; 1 blue, 5 green, 4 red; 9 green, 14 red, 6 blue; 8 blue, 15 red, 4 green; 7 green, 14 blue, 6 red
#  7 green, 9 red, 15 blue; 4 green, 6 red, 3 blue; 1 blue, 5 green, 4 red; 9 green, 14 red, 6 blue; 8 blue, 15 red, 4 green; 7 green, 14 blue, 6 red
# [' 7 green, 9 red, 15 blue', ' 4 green, 6 red, 3 blue', ' 1 blue, 5 green, 4 red', ' 9 green, 14 red, 6 blue', ' 8 blue, 15 red, 4 green', ' 7 green, 14 blue, 6 red']
# # ['7', 'green']
# # ['9', 'red']
# # ['15', 'blue']
# # ['4', 'green']
# # ['6', 'red']
# # ['3', 'blue']
# # ['1', 'blue']
# # ['5', 'green']
# # ['4', 'red']
# # ['9', 'green']
# # ['14', 'red']
# # ['6', 'blue']
# # ['8', 'blue']
# # ['15', 'red']
# # ['4', 'green']
# # ['7', 'green']
# # ['14', 'blue']
# # ['6', 'red']
# --- Game 68 : min_red = 15 min_green = 9 min_blue = 15 ---
#  --- POWER = 2025
# Game 69: 4 green; 2 blue; 4 green, 8 blue, 11 red; 3 green, 9 red, 4 blue; 1 red, 2 blue; 2 green, 5 blue, 11 red
#  4 green; 2 blue; 4 green, 8 blue, 11 red; 3 green, 9 red, 4 blue; 1 red, 2 blue; 2 green, 5 blue, 11 red
# [' 4 green', ' 2 blue', ' 4 green, 8 blue, 11 red', ' 3 green, 9 red, 4 blue', ' 1 red, 2 blue', ' 2 green, 5 blue, 11 red']
# # ['4', 'green']
# # ['2', 'blue']
# # ['4', 'green']
# # ['8', 'blue']
# # ['11', 'red']
# # ['3', 'green']
# # ['9', 'red']
# # ['4', 'blue']
# # ['1', 'red']
# # ['2', 'blue']
# # ['2', 'green']
# # ['5', 'blue']
# # ['11', 'red']
# --- Game 69 : min_red = 11 min_green = 4 min_blue = 8 ---
#  --- POWER = 352
# Game 70: 6 blue, 16 green, 4 red; 6 green, 13 red, 2 blue; 7 green, 1 red, 2 blue; 8 green, 4 blue, 1 red; 10 red, 11 green
#  6 blue, 16 green, 4 red; 6 green, 13 red, 2 blue; 7 green, 1 red, 2 blue; 8 green, 4 blue, 1 red; 10 red, 11 green
# [' 6 blue, 16 green, 4 red', ' 6 green, 13 red, 2 blue', ' 7 green, 1 red, 2 blue', ' 8 green, 4 blue, 1 red', ' 10 red, 11 green']
# # ['6', 'blue']
# # ['16', 'green']
# # ['4', 'red']
# # ['6', 'green']
# # ['13', 'red']
# # ['2', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# # ['2', 'blue']
# # ['8', 'green']
# # ['4', 'blue']
# # ['1', 'red']
# # ['10', 'red']
# # ['11', 'green']
# --- Game 70 : min_red = 13 min_green = 16 min_blue = 6 ---
#  --- POWER = 1248
# Game 71: 6 blue, 7 red; 10 blue, 2 green, 4 red; 12 red, 10 blue, 1 green
#  6 blue, 7 red; 10 blue, 2 green, 4 red; 12 red, 10 blue, 1 green
# [' 6 blue, 7 red', ' 10 blue, 2 green, 4 red', ' 12 red, 10 blue, 1 green']
# # ['6', 'blue']
# # ['7', 'red']
# # ['10', 'blue']
# # ['2', 'green']
# # ['4', 'red']
# # ['12', 'red']
# # ['10', 'blue']
# # ['1', 'green']
# --- Game 71 : min_red = 12 min_green = 2 min_blue = 10 ---
#  --- POWER = 240
# Game 72: 13 red, 13 blue; 6 red, 10 blue, 7 green; 3 blue, 5 green, 4 red; 8 green, 9 blue
#  13 red, 13 blue; 6 red, 10 blue, 7 green; 3 blue, 5 green, 4 red; 8 green, 9 blue
# [' 13 red, 13 blue', ' 6 red, 10 blue, 7 green', ' 3 blue, 5 green, 4 red', ' 8 green, 9 blue']
# # ['13', 'red']
# # ['13', 'blue']
# # ['6', 'red']
# # ['10', 'blue']
# # ['7', 'green']
# # ['3', 'blue']
# # ['5', 'green']
# # ['4', 'red']
# # ['8', 'green']
# # ['9', 'blue']
# --- Game 72 : min_red = 13 min_green = 8 min_blue = 13 ---
#  --- POWER = 1352
# Game 73: 1 red, 1 green, 8 blue; 1 green, 8 blue; 2 green, 6 blue; 2 blue; 1 red, 12 blue; 12 blue, 3 green
#  1 red, 1 green, 8 blue; 1 green, 8 blue; 2 green, 6 blue; 2 blue; 1 red, 12 blue; 12 blue, 3 green
# [' 1 red, 1 green, 8 blue', ' 1 green, 8 blue', ' 2 green, 6 blue', ' 2 blue', ' 1 red, 12 blue', ' 12 blue, 3 green']
# # ['1', 'red']
# # ['1', 'green']
# # ['8', 'blue']
# # ['1', 'green']
# # ['8', 'blue']
# # ['2', 'green']
# # ['6', 'blue']
# # ['2', 'blue']
# # ['1', 'red']
# # ['12', 'blue']
# # ['12', 'blue']
# # ['3', 'green']
# --- Game 73 : min_red = 1 min_green = 3 min_blue = 12 ---
#  --- POWER = 36
# Game 74: 2 blue, 1 green, 1 red; 3 blue, 1 red, 1 green; 3 blue, 2 red; 3 blue, 1 red; 1 green
#  2 blue, 1 green, 1 red; 3 blue, 1 red, 1 green; 3 blue, 2 red; 3 blue, 1 red; 1 green
# [' 2 blue, 1 green, 1 red', ' 3 blue, 1 red, 1 green', ' 3 blue, 2 red', ' 3 blue, 1 red', ' 1 green']
# # ['2', 'blue']
# # ['1', 'green']
# # ['1', 'red']
# # ['3', 'blue']
# # ['1', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# # ['2', 'red']
# # ['3', 'blue']
# # ['1', 'red']
# # ['1', 'green']
# --- Game 74 : min_red = 2 min_green = 1 min_blue = 3 ---
#  --- POWER = 6
# Game 75: 10 red, 1 green, 4 blue; 12 red, 11 blue, 9 green; 18 green, 14 red, 5 blue
#  10 red, 1 green, 4 blue; 12 red, 11 blue, 9 green; 18 green, 14 red, 5 blue
# [' 10 red, 1 green, 4 blue', ' 12 red, 11 blue, 9 green', ' 18 green, 14 red, 5 blue']
# # ['10', 'red']
# # ['1', 'green']
# # ['4', 'blue']
# # ['12', 'red']
# # ['11', 'blue']
# # ['9', 'green']
# # ['18', 'green']
# # ['14', 'red']
# # ['5', 'blue']
# --- Game 75 : min_red = 14 min_green = 18 min_blue = 11 ---
#  --- POWER = 2772
# Game 76: 4 blue, 3 green, 11 red; 4 blue, 1 green, 12 red; 11 blue, 2 green, 4 red; 2 blue, 2 green, 11 red; 12 red, 1 blue; 4 red, 2 green, 15 blue
#  4 blue, 3 green, 11 red; 4 blue, 1 green, 12 red; 11 blue, 2 green, 4 red; 2 blue, 2 green, 11 red; 12 red, 1 blue; 4 red, 2 green, 15 blue
# [' 4 blue, 3 green, 11 red', ' 4 blue, 1 green, 12 red', ' 11 blue, 2 green, 4 red', ' 2 blue, 2 green, 11 red', ' 12 red, 1 blue', ' 4 red, 2 green, 15 blue']
# # ['4', 'blue']
# # ['3', 'green']
# # ['11', 'red']
# # ['4', 'blue']
# # ['1', 'green']
# # ['12', 'red']
# # ['11', 'blue']
# # ['2', 'green']
# # ['4', 'red']
# # ['2', 'blue']
# # ['2', 'green']
# # ['11', 'red']
# # ['12', 'red']
# # ['1', 'blue']
# # ['4', 'red']
# # ['2', 'green']
# # ['15', 'blue']
# --- Game 76 : min_red = 12 min_green = 3 min_blue = 15 ---
#  --- POWER = 540
# Game 77: 2 red, 10 blue, 6 green; 6 blue, 2 red, 8 green; 1 red, 9 green, 7 blue
#  2 red, 10 blue, 6 green; 6 blue, 2 red, 8 green; 1 red, 9 green, 7 blue
# [' 2 red, 10 blue, 6 green', ' 6 blue, 2 red, 8 green', ' 1 red, 9 green, 7 blue']
# # ['2', 'red']
# # ['10', 'blue']
# # ['6', 'green']
# # ['6', 'blue']
# # ['2', 'red']
# # ['8', 'green']
# # ['1', 'red']
# # ['9', 'green']
# # ['7', 'blue']
# --- Game 77 : min_red = 2 min_green = 9 min_blue = 10 ---
#  --- POWER = 180
# Game 78: 3 green, 10 red; 2 blue, 4 red, 3 green; 8 red, 3 blue, 4 green; 1 blue, 7 red
#  3 green, 10 red; 2 blue, 4 red, 3 green; 8 red, 3 blue, 4 green; 1 blue, 7 red
# [' 3 green, 10 red', ' 2 blue, 4 red, 3 green', ' 8 red, 3 blue, 4 green', ' 1 blue, 7 red']
# # ['3', 'green']
# # ['10', 'red']
# # ['2', 'blue']
# # ['4', 'red']
# # ['3', 'green']
# # ['8', 'red']
# # ['3', 'blue']
# # ['4', 'green']
# # ['1', 'blue']
# # ['7', 'red']
# --- Game 78 : min_red = 10 min_green = 4 min_blue = 3 ---
#  --- POWER = 120
# Game 79: 4 green, 2 red; 2 red, 14 green; 1 blue, 5 green, 8 red; 4 red, 20 green; 3 green, 1 blue, 8 red; 4 green, 1 blue
#  4 green, 2 red; 2 red, 14 green; 1 blue, 5 green, 8 red; 4 red, 20 green; 3 green, 1 blue, 8 red; 4 green, 1 blue
# [' 4 green, 2 red', ' 2 red, 14 green', ' 1 blue, 5 green, 8 red', ' 4 red, 20 green', ' 3 green, 1 blue, 8 red', ' 4 green, 1 blue']
# # ['4', 'green']
# # ['2', 'red']
# # ['2', 'red']
# # ['14', 'green']
# # ['1', 'blue']
# # ['5', 'green']
# # ['8', 'red']
# # ['4', 'red']
# # ['20', 'green']
# # ['3', 'green']
# # ['1', 'blue']
# # ['8', 'red']
# # ['4', 'green']
# # ['1', 'blue']
# --- Game 79 : min_red = 8 min_green = 20 min_blue = 1 ---
#  --- POWER = 160
# Game 80: 2 green; 3 green, 13 red, 10 blue; 6 blue, 10 red, 1 green; 10 green, 12 red, 3 blue; 10 blue, 17 red, 5 green; 8 red, 2 blue, 6 green
#  2 green; 3 green, 13 red, 10 blue; 6 blue, 10 red, 1 green; 10 green, 12 red, 3 blue; 10 blue, 17 red, 5 green; 8 red, 2 blue, 6 green
# [' 2 green', ' 3 green, 13 red, 10 blue', ' 6 blue, 10 red, 1 green', ' 10 green, 12 red, 3 blue', ' 10 blue, 17 red, 5 green', ' 8 red, 2 blue, 6 green']
# # ['2', 'green']
# # ['3', 'green']
# # ['13', 'red']
# # ['10', 'blue']
# # ['6', 'blue']
# # ['10', 'red']
# # ['1', 'green']
# # ['10', 'green']
# # ['12', 'red']
# # ['3', 'blue']
# # ['10', 'blue']
# # ['17', 'red']
# # ['5', 'green']
# # ['8', 'red']
# # ['2', 'blue']
# # ['6', 'green']
# --- Game 80 : min_red = 17 min_green = 10 min_blue = 10 ---
#  --- POWER = 1700
# Game 81: 4 green, 2 blue, 4 red; 16 red, 1 blue, 20 green; 7 blue, 10 red, 9 green; 7 blue, 2 green, 14 red
#  4 green, 2 blue, 4 red; 16 red, 1 blue, 20 green; 7 blue, 10 red, 9 green; 7 blue, 2 green, 14 red
# [' 4 green, 2 blue, 4 red', ' 16 red, 1 blue, 20 green', ' 7 blue, 10 red, 9 green', ' 7 blue, 2 green, 14 red']
# # ['4', 'green']
# # ['2', 'blue']
# # ['4', 'red']
# # ['16', 'red']
# # ['1', 'blue']
# # ['20', 'green']
# # ['7', 'blue']
# # ['10', 'red']
# # ['9', 'green']
# # ['7', 'blue']
# # ['2', 'green']
# # ['14', 'red']
# --- Game 81 : min_red = 16 min_green = 20 min_blue = 7 ---
#  --- POWER = 2240
# Game 82: 4 blue, 8 green, 5 red; 14 red, 8 blue, 1 green; 11 red, 13 green
#  4 blue, 8 green, 5 red; 14 red, 8 blue, 1 green; 11 red, 13 green
# [' 4 blue, 8 green, 5 red', ' 14 red, 8 blue, 1 green', ' 11 red, 13 green']
# # ['4', 'blue']
# # ['8', 'green']
# # ['5', 'red']
# # ['14', 'red']
# # ['8', 'blue']
# # ['1', 'green']
# # ['11', 'red']
# # ['13', 'green']
# --- Game 82 : min_red = 14 min_green = 13 min_blue = 8 ---
#  --- POWER = 1456
# Game 83: 2 blue, 2 green, 10 red; 10 green, 4 red, 3 blue; 11 green, 14 red, 4 blue; 2 blue, 11 red; 3 blue, 1 green, 4 red
#  2 blue, 2 green, 10 red; 10 green, 4 red, 3 blue; 11 green, 14 red, 4 blue; 2 blue, 11 red; 3 blue, 1 green, 4 red
# [' 2 blue, 2 green, 10 red', ' 10 green, 4 red, 3 blue', ' 11 green, 14 red, 4 blue', ' 2 blue, 11 red', ' 3 blue, 1 green, 4 red']
# # ['2', 'blue']
# # ['2', 'green']
# # ['10', 'red']
# # ['10', 'green']
# # ['4', 'red']
# # ['3', 'blue']
# # ['11', 'green']
# # ['14', 'red']
# # ['4', 'blue']
# # ['2', 'blue']
# # ['11', 'red']
# # ['3', 'blue']
# # ['1', 'green']
# # ['4', 'red']
# --- Game 83 : min_red = 14 min_green = 11 min_blue = 4 ---
#  --- POWER = 616
# Game 84: 12 blue, 9 green, 10 red; 1 red, 6 green, 4 blue; 7 red, 3 green, 16 blue; 3 green, 3 blue
#  12 blue, 9 green, 10 red; 1 red, 6 green, 4 blue; 7 red, 3 green, 16 blue; 3 green, 3 blue
# [' 12 blue, 9 green, 10 red', ' 1 red, 6 green, 4 blue', ' 7 red, 3 green, 16 blue', ' 3 green, 3 blue']
# # ['12', 'blue']
# # ['9', 'green']
# # ['10', 'red']
# # ['1', 'red']
# # ['6', 'green']
# # ['4', 'blue']
# # ['7', 'red']
# # ['3', 'green']
# # ['16', 'blue']
# # ['3', 'green']
# # ['3', 'blue']
# --- Game 84 : min_red = 10 min_green = 9 min_blue = 16 ---
#  --- POWER = 1440
# Game 85: 2 red, 4 blue; 4 blue, 1 green, 6 red; 9 blue, 1 red; 1 green, 4 blue, 10 red; 5 green, 7 red, 17 blue
#  2 red, 4 blue; 4 blue, 1 green, 6 red; 9 blue, 1 red; 1 green, 4 blue, 10 red; 5 green, 7 red, 17 blue
# [' 2 red, 4 blue', ' 4 blue, 1 green, 6 red', ' 9 blue, 1 red', ' 1 green, 4 blue, 10 red', ' 5 green, 7 red, 17 blue']
# # ['2', 'red']
# # ['4', 'blue']
# # ['4', 'blue']
# # ['1', 'green']
# # ['6', 'red']
# # ['9', 'blue']
# # ['1', 'red']
# # ['1', 'green']
# # ['4', 'blue']
# # ['10', 'red']
# # ['5', 'green']
# # ['7', 'red']
# # ['17', 'blue']
# --- Game 85 : min_red = 10 min_green = 5 min_blue = 17 ---
#  --- POWER = 850
# Game 86: 2 red, 3 blue, 1 green; 2 blue, 2 red, 2 green; 10 blue, 2 green; 5 green, 4 red, 6 blue
#  2 red, 3 blue, 1 green; 2 blue, 2 red, 2 green; 10 blue, 2 green; 5 green, 4 red, 6 blue
# [' 2 red, 3 blue, 1 green', ' 2 blue, 2 red, 2 green', ' 10 blue, 2 green', ' 5 green, 4 red, 6 blue']
# # ['2', 'red']
# # ['3', 'blue']
# # ['1', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# # ['2', 'green']
# # ['10', 'blue']
# # ['2', 'green']
# # ['5', 'green']
# # ['4', 'red']
# # ['6', 'blue']
# --- Game 86 : min_red = 4 min_green = 5 min_blue = 10 ---
#  --- POWER = 200
# Game 87: 1 red, 7 blue, 9 green; 3 green, 2 blue; 1 red, 4 blue, 10 green; 10 green, 7 blue, 1 red; 6 blue, 9 green; 9 blue, 7 green, 1 red
#  1 red, 7 blue, 9 green; 3 green, 2 blue; 1 red, 4 blue, 10 green; 10 green, 7 blue, 1 red; 6 blue, 9 green; 9 blue, 7 green, 1 red
# [' 1 red, 7 blue, 9 green', ' 3 green, 2 blue', ' 1 red, 4 blue, 10 green', ' 10 green, 7 blue, 1 red', ' 6 blue, 9 green', ' 9 blue, 7 green, 1 red']
# # ['1', 'red']
# # ['7', 'blue']
# # ['9', 'green']
# # ['3', 'green']
# # ['2', 'blue']
# # ['1', 'red']
# # ['4', 'blue']
# # ['10', 'green']
# # ['10', 'green']
# # ['7', 'blue']
# # ['1', 'red']
# # ['6', 'blue']
# # ['9', 'green']
# # ['9', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# --- Game 87 : min_red = 1 min_green = 10 min_blue = 9 ---
#  --- POWER = 90
# Game 88: 1 blue, 14 red, 9 green; 4 green, 9 red; 8 green, 1 blue, 10 red
#  1 blue, 14 red, 9 green; 4 green, 9 red; 8 green, 1 blue, 10 red
# [' 1 blue, 14 red, 9 green', ' 4 green, 9 red', ' 8 green, 1 blue, 10 red']
# # ['1', 'blue']
# # ['14', 'red']
# # ['9', 'green']
# # ['4', 'green']
# # ['9', 'red']
# # ['8', 'green']
# # ['1', 'blue']
# # ['10', 'red']
# --- Game 88 : min_red = 14 min_green = 9 min_blue = 1 ---
#  --- POWER = 126
# Game 89: 13 red, 1 green; 2 blue, 10 red; 1 green, 3 blue, 13 red; 1 green, 14 red, 3 blue; 2 green, 6 red; 1 green, 12 red
#  13 red, 1 green; 2 blue, 10 red; 1 green, 3 blue, 13 red; 1 green, 14 red, 3 blue; 2 green, 6 red; 1 green, 12 red
# [' 13 red, 1 green', ' 2 blue, 10 red', ' 1 green, 3 blue, 13 red', ' 1 green, 14 red, 3 blue', ' 2 green, 6 red', ' 1 green, 12 red']
# # ['13', 'red']
# # ['1', 'green']
# # ['2', 'blue']
# # ['10', 'red']
# # ['1', 'green']
# # ['3', 'blue']
# # ['13', 'red']
# # ['1', 'green']
# # ['14', 'red']
# # ['3', 'blue']
# # ['2', 'green']
# # ['6', 'red']
# # ['1', 'green']
# # ['12', 'red']
# --- Game 89 : min_red = 14 min_green = 2 min_blue = 3 ---
#  --- POWER = 84
# Game 90: 1 red, 2 blue, 9 green; 1 blue, 3 red, 2 green; 10 green, 9 red; 1 red, 9 green, 4 blue; 3 blue, 13 green, 13 red
#  1 red, 2 blue, 9 green; 1 blue, 3 red, 2 green; 10 green, 9 red; 1 red, 9 green, 4 blue; 3 blue, 13 green, 13 red
# [' 1 red, 2 blue, 9 green', ' 1 blue, 3 red, 2 green', ' 10 green, 9 red', ' 1 red, 9 green, 4 blue', ' 3 blue, 13 green, 13 red']
# # ['1', 'red']
# # ['2', 'blue']
# # ['9', 'green']
# # ['1', 'blue']
# # ['3', 'red']
# # ['2', 'green']
# # ['10', 'green']
# # ['9', 'red']
# # ['1', 'red']
# # ['9', 'green']
# # ['4', 'blue']
# # ['3', 'blue']
# # ['13', 'green']
# # ['13', 'red']
# --- Game 90 : min_red = 13 min_green = 13 min_blue = 4 ---
#  --- POWER = 676
# Game 91: 2 red, 8 green, 8 blue; 3 green, 2 red, 6 blue; 5 green, 4 red
#  2 red, 8 green, 8 blue; 3 green, 2 red, 6 blue; 5 green, 4 red
# [' 2 red, 8 green, 8 blue', ' 3 green, 2 red, 6 blue', ' 5 green, 4 red']
# # ['2', 'red']
# # ['8', 'green']
# # ['8', 'blue']
# # ['3', 'green']
# # ['2', 'red']
# # ['6', 'blue']
# # ['5', 'green']
# # ['4', 'red']
# --- Game 91 : min_red = 4 min_green = 8 min_blue = 8 ---
#  --- POWER = 256
# Game 92: 8 green, 12 blue, 4 red; 7 red, 4 green; 4 blue, 7 green, 7 red; 7 blue, 5 green
#  8 green, 12 blue, 4 red; 7 red, 4 green; 4 blue, 7 green, 7 red; 7 blue, 5 green
# [' 8 green, 12 blue, 4 red', ' 7 red, 4 green', ' 4 blue, 7 green, 7 red', ' 7 blue, 5 green']
# # ['8', 'green']
# # ['12', 'blue']
# # ['4', 'red']
# # ['7', 'red']
# # ['4', 'green']
# # ['4', 'blue']
# # ['7', 'green']
# # ['7', 'red']
# # ['7', 'blue']
# # ['5', 'green']
# --- Game 92 : min_red = 7 min_green = 8 min_blue = 12 ---
#  --- POWER = 672
# Game 93: 1 green, 1 red, 2 blue; 3 green, 1 red, 3 blue; 1 red, 8 blue; 1 green, 13 blue; 1 red, 4 blue, 4 green
#  1 green, 1 red, 2 blue; 3 green, 1 red, 3 blue; 1 red, 8 blue; 1 green, 13 blue; 1 red, 4 blue, 4 green
# [' 1 green, 1 red, 2 blue', ' 3 green, 1 red, 3 blue', ' 1 red, 8 blue', ' 1 green, 13 blue', ' 1 red, 4 blue, 4 green']
# # ['1', 'green']
# # ['1', 'red']
# # ['2', 'blue']
# # ['3', 'green']
# # ['1', 'red']
# # ['3', 'blue']
# # ['1', 'red']
# # ['8', 'blue']
# # ['1', 'green']
# # ['13', 'blue']
# # ['1', 'red']
# # ['4', 'blue']
# # ['4', 'green']
# --- Game 93 : min_red = 1 min_green = 4 min_blue = 13 ---
#  --- POWER = 52
# Game 94: 2 blue, 7 red, 17 green; 2 green, 1 blue, 5 red; 3 blue, 7 green, 1 red; 6 red, 1 blue, 1 green; 1 green, 1 blue, 1 red
#  2 blue, 7 red, 17 green; 2 green, 1 blue, 5 red; 3 blue, 7 green, 1 red; 6 red, 1 blue, 1 green; 1 green, 1 blue, 1 red
# [' 2 blue, 7 red, 17 green', ' 2 green, 1 blue, 5 red', ' 3 blue, 7 green, 1 red', ' 6 red, 1 blue, 1 green', ' 1 green, 1 blue, 1 red']
# # ['2', 'blue']
# # ['7', 'red']
# # ['17', 'green']
# # ['2', 'green']
# # ['1', 'blue']
# # ['5', 'red']
# # ['3', 'blue']
# # ['7', 'green']
# # ['1', 'red']
# # ['6', 'red']
# # ['1', 'blue']
# # ['1', 'green']
# # ['1', 'green']
# # ['1', 'blue']
# # ['1', 'red']
# --- Game 94 : min_red = 7 min_green = 17 min_blue = 3 ---
#  --- POWER = 357
# Game 95: 4 blue, 3 green, 4 red; 17 red, 2 blue; 6 blue, 16 green, 15 red; 7 blue, 17 green; 1 red, 3 green, 3 blue; 7 red, 14 green, 4 blue
#  4 blue, 3 green, 4 red; 17 red, 2 blue; 6 blue, 16 green, 15 red; 7 blue, 17 green; 1 red, 3 green, 3 blue; 7 red, 14 green, 4 blue
# [' 4 blue, 3 green, 4 red', ' 17 red, 2 blue', ' 6 blue, 16 green, 15 red', ' 7 blue, 17 green', ' 1 red, 3 green, 3 blue', ' 7 red, 14 green, 4 blue']
# # ['4', 'blue']
# # ['3', 'green']
# # ['4', 'red']
# # ['17', 'red']
# # ['2', 'blue']
# # ['6', 'blue']
# # ['16', 'green']
# # ['15', 'red']
# # ['7', 'blue']
# # ['17', 'green']
# # ['1', 'red']
# # ['3', 'green']
# # ['3', 'blue']
# # ['7', 'red']
# # ['14', 'green']
# # ['4', 'blue']
# --- Game 95 : min_red = 17 min_green = 17 min_blue = 7 ---
#  --- POWER = 2023
# Game 96: 6 red, 3 blue; 7 green, 5 blue, 10 red; 9 green, 1 blue; 6 blue, 1 red, 12 green; 3 blue, 10 green
#  6 red, 3 blue; 7 green, 5 blue, 10 red; 9 green, 1 blue; 6 blue, 1 red, 12 green; 3 blue, 10 green
# [' 6 red, 3 blue', ' 7 green, 5 blue, 10 red', ' 9 green, 1 blue', ' 6 blue, 1 red, 12 green', ' 3 blue, 10 green']
# # ['6', 'red']
# # ['3', 'blue']
# # ['7', 'green']
# # ['5', 'blue']
# # ['10', 'red']
# # ['9', 'green']
# # ['1', 'blue']
# # ['6', 'blue']
# # ['1', 'red']
# # ['12', 'green']
# # ['3', 'blue']
# # ['10', 'green']
# --- Game 96 : min_red = 10 min_green = 12 min_blue = 6 ---
#  --- POWER = 720
# Game 97: 3 green, 1 red, 13 blue; 1 red, 8 green, 2 blue; 1 green, 2 blue, 2 red; 1 red, 4 green, 9 blue
#  3 green, 1 red, 13 blue; 1 red, 8 green, 2 blue; 1 green, 2 blue, 2 red; 1 red, 4 green, 9 blue
# [' 3 green, 1 red, 13 blue', ' 1 red, 8 green, 2 blue', ' 1 green, 2 blue, 2 red', ' 1 red, 4 green, 9 blue']
# # ['3', 'green']
# # ['1', 'red']
# # ['13', 'blue']
# # ['1', 'red']
# # ['8', 'green']
# # ['2', 'blue']
# # ['1', 'green']
# # ['2', 'blue']
# # ['2', 'red']
# # ['1', 'red']
# # ['4', 'green']
# # ['9', 'blue']
# --- Game 97 : min_red = 2 min_green = 8 min_blue = 13 ---
#  --- POWER = 208
# Game 98: 1 green, 8 red, 7 blue; 8 blue, 8 red, 3 green; 1 blue, 2 red; 4 red, 7 blue; 3 green, 3 blue, 3 red
#  1 green, 8 red, 7 blue; 8 blue, 8 red, 3 green; 1 blue, 2 red; 4 red, 7 blue; 3 green, 3 blue, 3 red
# [' 1 green, 8 red, 7 blue', ' 8 blue, 8 red, 3 green', ' 1 blue, 2 red', ' 4 red, 7 blue', ' 3 green, 3 blue, 3 red']
# # ['1', 'green']
# # ['8', 'red']
# # ['7', 'blue']
# # ['8', 'blue']
# # ['8', 'red']
# # ['3', 'green']
# # ['1', 'blue']
# # ['2', 'red']
# # ['4', 'red']
# # ['7', 'blue']
# # ['3', 'green']
# # ['3', 'blue']
# # ['3', 'red']
# --- Game 98 : min_red = 8 min_green = 3 min_blue = 8 ---
#  --- POWER = 192
# Game 99: 9 blue, 14 red; 3 blue, 10 red, 5 green; 3 blue, 3 green, 6 red
#  9 blue, 14 red; 3 blue, 10 red, 5 green; 3 blue, 3 green, 6 red
# [' 9 blue, 14 red', ' 3 blue, 10 red, 5 green', ' 3 blue, 3 green, 6 red']
# # ['9', 'blue']
# # ['14', 'red']
# # ['3', 'blue']
# # ['10', 'red']
# # ['5', 'green']
# # ['3', 'blue']
# # ['3', 'green']
# # ['6', 'red']
# --- Game 99 : min_red = 14 min_green = 5 min_blue = 9 ---
#  --- POWER = 630
# Game 100: 12 blue, 2 green; 2 green, 4 red, 13 blue; 9 blue, 1 red, 2 green; 2 green, 3 red, 1 blue
#  12 blue, 2 green; 2 green, 4 red, 13 blue; 9 blue, 1 red, 2 green; 2 green, 3 red, 1 blue
# [' 12 blue, 2 green', ' 2 green, 4 red, 13 blue', ' 9 blue, 1 red, 2 green', ' 2 green, 3 red, 1 blue']
# # ['12', 'blue']
# # ['2', 'green']
# # ['2', 'green']
# # ['4', 'red']
# # ['13', 'blue']
# # ['9', 'blue']
# # ['1', 'red']
# # ['2', 'green']
# # ['2', 'green']
# # ['3', 'red']
# # ['1', 'blue']
# --- Game 100 : min_red = 4 min_green = 2 min_blue = 13 ---
#  --- POWER = 104
# *Sum of powers of ALL games: 63981

# %%
# # *** !!! TESTING !!! ***
# # =====================================================================================================================
# arrSet = ' red'
# lineDigits = re.findall(r'\d', arrSet)


# if lineDigits:
#     print('not empty')
# else:
#     print('empty')

# print(arrSet.find('red'))
# print(lineDigits)
