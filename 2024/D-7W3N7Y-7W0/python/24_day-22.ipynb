# %% [markdown]
# # Day 22: Monkey Market

# %% [markdown]
# ## Import libraries

# %%
import copy
# from functools import lru_cache

# %% [markdown]
# ## Import data

# %%
# *** [IMPORT DATA] ***
# NOTE: In the given puzzle input:
# - EACh line stores the secret number of EACh buyer.
# ====================================================================================================================
# ! Open the file for reading mode (= default mode if the mode is not specified)
file = open("../data/24_day-22_input-test.txt", "r") 

# Read all the data in the file
file_data = file.read().strip()

# Split by claw machines
file_data = file_data.split("\n")

print(file_data)
# ====================================================================================================================

# %% [markdown]
# ## Helper functions

# %%
# ====================================================================================================================

# %% [markdown]
# ## Part 1

# %%
# *** [PART 1] ***
# ! PROBLEM: As you're all teleported deep into the jungle, a monkey steals The Historians' device! You'll need to get it back while The Historians are looking for the Chief. You aren't sure how the Monkey Exchange Market works, but one of The Historians senses trouble and comes over to help. Apparently, they've been studying these monkeys for a while and have deciphered their *secrets*. Today, the Market is full of monkeys buying *good hiding spots*. Fortunately, because of the time you recently spent in this jungle, you know lots of good hiding spots you can sell! If you sell enough hiding spots, you should be able to get enough bananas to buy the device back.
# - NOTE: Each buyer produces a pseudorandom sequence of secret numbers, where EACH secret no. is derived from the PREVIOUS secret no. in the sequence via the following process:
#   - secret_number = PRUNE((MIX(secret_number * 64)))
#   - secret_number = PRUNE(MIX(ROUND_DOWN((secret_number / 32), nearest_int)))
#   - secret_number = PRUNE(MIX(secret_number * 2048))
# - NOTE: MIX: Bitwise XOR between given value and secret number.
# - NOTE: PRUNE: secretnumber % 16777216.
# - NOTE: After the abovementioned process completes, the buyer is left with the ENXT secret number in the sequence. The buyer can repeat this process as many times as necessary to produce more secret numbers.
# - NOTE: EACH buyer uses their OWN secret number when choosing their price, so it's important to be able to predict the sequence of secret numbers for EACH buyer. Fortunately, the Historian's research has uncovered the INITIAL secret number of EACH buyer = your puzzle input.
# ! TODO: For each buyer, simulate the creation of 2000 new secret numbers and then calculate the sum of the 2000th secret number generated by EACH buyer.
# ====================================================================================================================
# ! Create a deep (independent) copy of the data, such that changes made to the copy do not affect the original data to still test/re-run in Part 1/2 with the correct INITIAL (and not modified) data
# - NOTE: Not using a deep copy will modify the original data after running Part 1/2, therefore incorrect output will be calculated.
var = copy.deepcopy(file_data)



# ====================================================================================================================

# %% [markdown]
# ## Part 2

# %%
# *** [PART 2] ***
# ! PROBLEM: xxx
# ! TODO: xxx
#====================================================================================================================
# ! Create a deep (independent) copy of the data, such that changes made to the copy do not affect the original data to still test/re-run Part in 1/2 with the correct INITIAL (and not modified) data
# - NOTE: Not using a deep copy will modify the original data after running Part 1/2, therefore incorrect output will be calculated.
var = copy.deepcopy(file_data)
